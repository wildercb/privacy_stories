# %% [markdown]
# First load the annotations into individual text files which can be read in for processing.
#
# Privacy policies will be broken into sections of annotations and read to create a structure of which actions data types and purposes appear in each section. Each section meaning all phrases within the policy where actions data types and purposes are connected to each other.
#
# This will give us information to append to a graph of the privacy stories within the individual policies.

# %%
import os 
import re
from docx import Document


# Running the function with the updated file path
docx_path = '../policies_annotated/Annotated policies.docx'
annotation_dir = '../policies_annotated/annotated_policies'

def extract_annotations(docx_path, annotation_dir):
    # Load the document
    doc = Document(docx_path)

    # Create the output directory if it doesn't exist
    if not os.path.exists(annotation_dir):
        os.makedirs(annotation_dir)

    # Initialize variables to keep track of sections
    current_id = None
    current_privacy_policy = None
    current_data_safety = None
    in_privacy_policy = False
    in_data_safety = False

    info = []
    # Iterate through the paragraphs in the document
    for para in doc.paragraphs:
        if para.style.name == 'Heading 5':  # ID
            # Save previous section's data if available
            if current_id is not None:
                try:
                    save_policy(annotation_dir, current_id, current_privacy_policy, current_data_safety)
                except:
                    print(f'error with {current_id}')

            # Reset variables for the new section
            current_id = para.text.replace('ID: ', '').strip()  # Remove 'ID: ' prefix and trailing spaces
            current_privacy_policy = ''
            current_data_safety = ''
            in_privacy_policy = False
            in_data_safety = False

        elif para.style.name == 'Heading 4':
            if 'privacy' in para.text.lower():
                # We reached the privacy policy section
                in_privacy_policy = True
                in_data_safety = False
            elif 'data' in para.text.lower():
                # We are entering the data safety section
                in_data_safety = True
                in_privacy_policy = False

        elif in_privacy_policy:
            # Add text to the privacy policy
            current_privacy_policy += para.text + '\n'

        elif in_data_safety:
            # Add text to the data safety
            current_data_safety += para.text + '\n'
    
    # Save the last section's data
    if current_id is not None:
        try:
            save_policy(annotation_dir, current_id, current_privacy_policy, current_data_safety)
        except:
            print(f'error with {current_id}')

extract_annotations(docx_path, annotation_dir)

def save_policy(annotation_dir, policy_id, privacy_policy, data_safety):
    # Create a subfolder for the policy, ensuring path is normalized
    policy_folder = os.path.join(annotation_dir, policy_id)
    if not os.path.exists(policy_folder):
        os.makedirs(policy_folder)

    # Save the privacy policy text
    privacy_policy_path = os.path.join(policy_folder, 'privacy_policy.txt')
    with open(privacy_policy_path, 'w', encoding='utf-8') as file:
        file.write(privacy_policy)

    # Save the data safety text
    data_safety_path = os.path.join(policy_folder, 'data_safety.txt')
    with open(data_safety_path, 'w', encoding='utf-8') as file:
        file.write(data_safety)

def extract_annotations_and_tags(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()

    # Regex patterns for annotations and individual tags
    annotation_pattern = r'\{\#s(.*?)\}'
    action_pattern = r'\[\#a(.*?)\]'
    data_type_pattern = r'\[\#dt(.*?)\]'
    purpose_pattern = r'\[\#p(.*?)\]'

    # Extracting annotations
    annotations = re.findall(annotation_pattern, text, re.DOTALL)

    # Extracting individual tags within each annotation
    actions = set()
    data_types = set()
    purposes = set()
    for annotation in annotations:
        actions.update(re.findall(action_pattern, annotation))
        data_types.update(re.findall(data_type_pattern, annotation))
        purposes.update(re.findall(purpose_pattern, annotation))

    return annotations, list(actions), list(data_types), list(purposes)

annotations_results = {}

# Iterate through all directories within 'annotated_policies'
for app_dir in os.listdir(annotation_dir):
    app_directory_path = os.path.join(annotation_dir, app_dir)

    # Check if it's a directory
    if os.path.isdir(app_directory_path):
        # Iterate through all files named 'privacy_policy.txt' within the app directory
        for file_name in os.listdir(app_directory_path):
            if file_name == 'privacy_policy.txt':
                file_path = os.path.join(app_directory_path, file_name)
                annotations, actions, data_types, purposes = extract_annotations_and_tags(file_path)
                result_key = os.path.join(app_dir, file_name)
                annotations_results[result_key] = {
                    'Annotations': annotations,
                    'Actions': actions,
                    'Data Types': data_types,
                    'Purposes': purposes
                }

# Print the results for all directories
for result_key, result_data in annotations_results.items():
    print(f"Results for {result_key}:")
    print(result_data)
# Out:
# error with Description:
# error with Privacy policy:
# error with Description:
# error with Privacy policy:
# error with Id: com.canvism
# error with Id: com.marblehead.mobile
# Results for afmstudio.craigslistclassifiedslocal\privacy_policy.txt:
# {'Annotations': [' We [#a collect] [#dt personal information] to [#p provide and enhance our Services]./', " we [#a collect] and how we obtain it. 2.1 Information Provided by You During your registration or use of our Services, you may voluntarily provide the following personal information: [#dt Email address] [#dt Mobile telephone number] [# dt Geographic location] [#dt Profile picture] [#dt User ID]  [#dt Facebook] or [#dt Google account details] [#dt Driver's license] or other [#dt government ID] /", ' Information [#a Collected] Automatically When you interact with our Platform or use our Services, we automatically [#a collect] the following information about you: [#dt Device Information:][#dt Operating system version], [#dt device make and model], [#dt and mobile network details]. [#dt Location Information]: Depending on permissions, we may collect [#dt  location data] using methods like [#dt IP address], [#dt GPS],[#dt  Wi-Fi access points], and [#dt mobile towers]. Client and Log Data: Technical details like [#dt IP address], [#dt time zone], [#dt operating system], [#dt login information], and [#dt browser type]. Usage Information: Details of your [#dt activity on our Platform], including [#dt visit timestamps], [#dt clicked advertisements], [#dt interaction with ads], [#dt duration of visits], and [#dt content viewing order]. /', ' Cookies: If you access Services through a web browser, we [#a use] [#dt cookies] for [#p session management], [#p storing preferences], language selection, and [#p targeted advertising]. /', ' We may [#a(external:collect) collect [#dt personal information] from third-party sources]. For instance, we use third-party machine learning software to [#p analyze communications] in our chat feature to [#p prevent fraud and block spam or abusive messages] /', ' is [#a  stored] as [#dt chat messages]. /', ' [#p Identifying] you as a user and providing access to your account settings. Making [#p suggestions and recommendations] about our Services. Offering [#p tailored content] and improving your experience on the Platform. [#p Monitoring campaign effectiveness] and [#p preventing repetitive display of items]. Enhancing performance, [#p personalizing content], and [#p measuring interactions with advertisements]. 3.2 Safety and Security Administering and protecting our Platform, including troubleshooting, data analysis, and fraud prevention. [#p Analyzing communications] in chat for [#p safety and blocking abusive messages]. SMS verification of your telephone number to increase trust and safety. 3.3 Other Purposes Aggregating or de-identifying data for analysis, [#p segmentation], and [#p development of anonymous profiles]. /', ' We may [#a share] your [#dt personal information] with the following parties: [#p Corporate affiliates] [#p Third-party vendors] and service providers [#p Advertisers] [#p Analytics providers] [#p Law enforcement authorities], [#p regulators], [#p courts], and [#p government bodies] [#p Business transfer] /', ' We may [#p communicate with you via email or in-app notifications] related to our Services, including registration confirmations and transactional messages. We may also [#p(advertisement) send you marketing communications] about our Services /'], 'Actions': [' share', ' Collected', ' collect', ' use', '(external:collect) collect [#dt personal information', '  stored'], 'Data Types': [' device make and model', ' Location Information', ' time zone', ' visit timestamps', ' personal information', ' Operating system version', ' operating system', ' GPS', '  Wi-Fi access points', ' User ID', ' Profile picture', ' interaction with ads', ' Mobile telephone number', '  location data', ' content viewing order', ' mobile towers', ' IP address', ' duration of visits', ' Facebook', ' Google account details', ' cookies', ' Email address', ' clicked advertisements', ' Device Information:', ' chat messages', " Driver's license", ' browser type', ' activity on our Platform', ' government ...
# Results for ai.appfront.luckyslice\privacy_policy.txt:
# {'Annotations': [' INCLUDING TO THE [#a COLLECTION] AND\n[#a PROCESSING] OF YOUR [#dt PERSONAL INFORMATION] /', ' We may [#a collect] two types of data\nand information from our Users:\na.\nThe first type of information is non-identifiable\nand anonymous information ( " [#dt Non-personal\nInformation] " ). /', ' [#dt Non-personal Information] which is being [#a (collected) gathered] consists\nof technical information and behavioral information, and may contain, among\nother things, [#dt type of mobile device] and [#dt operating system], number of stamps,\n[#dt places users have stamped], etc. We also collect Non-personal Information which\nyou provide us voluntarily in order to active the App, namely, your [#dt phone\nNumber.] \nb.\nThe second type of information is individually identifiable\ninformation ( "Personal Information ").\nThis information may identify\nan individual or may be of a private and/or sensitive nature . Personal\nInformation may include, without limitation, [#dt User\'s name], [#dt email address], [#dt date\nof birthday] and certain [#dt personal eating preferences] /', ' We [#a collect] [#dt Non-Personal Information] through your\nuse of the Site and/or App . In other words, when you are using the Site\nand/or App we are aware of it and may gather, [#a collect] and record the\ninformation relating to such usage.\nWe also [#a collect]\n[#dt Non-personal Information] which you provide us voluntarily in order to [#p(functionality) active\nthe App], namely, your [#dt phone number] . /', ' We [#a collect] [#dt Personal Information]\nwhich you provide us voluntarily\nwhen you insert such Personal Information into the\n"Me" segment of the App or when you purchase Beengo Cards using Your\ncredit card. We [#a store] the [#dt Personal Information] either independently or through\nthe help of our authorized third-party service providers as detailed below./', ' [#dt Non-personal Information] is\n[#a collected] in order to:\n·\n[#p (analytics) Use it for\nstatistical and research purposes] and for [#p customization and improvement of the App\nand/or Site.] /', " [#p Activate the App]\n[#a using] [#dt User's phone number.] /", "  [#p(marketing) special offers related to the Food\nEstablishments] [#p(customization) in accordance with the User's personal eating preferences.]\n·\n[#p(marketing) Send to the User’s email address gifts], for example on the User’s birthday (for example, free coffee) and/or any promotional emails on behalf of the Food Establishments which we cooperate with.\n·\nAllow Users to\n[#p(payments:functionality) purchase certain Beengo Cards] (namely, charging cards) through online payment methods\n(namely, ZOOZ).\n·\nSend to User's\nemail address confirmation regarding the purchase of Beengo Cards as well as a\nunique PIN code to be used vis-à-vis the purchased Beengo Cards.\n·\nAllow Users to\nprovide\n[#p feedback with respect to Food Establishments they visit.] /", " Beengo\nmay [#a(share:third party) disclose Personal Information] in the following cases:\n(a) [#p(requirements:legal requirements) to satisfy any applicable law, regulation, legal process, subpoena or\ngovernmental request;] (b) [#p(requirements) to enforce this Privacy Policy and/or the TOU], including\ninvestigation of potential violations thereof; (c) to [#p(security) detect, prevent, or otherwise address fraud, security or technical issues;] (d) to [#p(requirements) respond to User's\nsupport requests]; (e) [#p(requirements:privacy policy compliance) respond to claims that any content available on the Site violates the rights of third-parties]; /", ' may be [#a(share) using third party software and/or App], in order to [#a collect, store] and/or\n[#a process] the information detailed herein. Such software/App include without\n limitation, Amazon cloud services which privacy policy can be found at:\nhttp://aws.amazon.com/privacy/\nand PayPal\nwebsite or services (as detailed below).\n8.\nPayment]\nBeengo accepts payment through c ...
# Results for ai.blueplate.app\privacy_policy.txt:
# {'Annotations': [' Privacy We [#a collect] [#dt(contact data) consumer information], including but not limited to: [#dt Phone Number], [#dt Email], [#dt Spending] and [#dt(app interactions) Site Visit Habits], [#dt Full name], and [#dt address]. By making a purchase and inputting your information,  you agree to us [#a collecting], [#a storing], and [#a using] your data in the following ways. 1: The restaurant may [#p contact you regarding food items or order conditions] for example, to tell you a food item is unavailable, to adjust the fulfillment time, etc. 2: The restaurant and its employees will be able to  see your basic information to make reference to your order or to get in [#p contact with you in case of any changes, or to provide you with order updates.] Employees and owners are not allowed to contact customers for any other purposes than what is within reason to provide order updates. If you suspect abuse, please email support@blueplate.ai immediately. 3: You may be [#p contacted by the Online Ordering Provider (Blueplate) to ask for your feedback regarding the online ordering system] 4: You will be [#p(contact) sent, by our automatic system, an order confirmation email] /', ' Your [#dt email] may be [#a(share) stored by Sendgrid, a Twilio Product], /', ' We may [#a(process:aggregate) use your data in the aggregate] to make [#p(analytics) actionable insights in real time to other restaurants and their employees]./', ' our system may [#a use] your [#dt spending habits] to attempt to [#p(analytics:user habits) predict popular times and rush times], sharing this information with restaurant employees to [#p(analytics:user habits)  prepare appropriately for when they might get busy.] /', ' We may [#a use] [#dt(personal data) data about you] to [#p(customization) link actions across the platform and attribute them to you], for example if you use the same [#dt(spending) card] or the same [#dt email address] on two different platform actions, we’ll [#p(customization) link them to your customer profile] /', ' We may [#a collect] [#dt(app interactions) data about your visit and site habits], such as [#dt(app interactions:clicks) what you click on], how you [#dt(app interactions) interact with the site], [#dt(app interactions:visit timestamps) how long you visit for], and more.', ' We may [#a collect] your [#dt IP address] and other [#dt information regarding your internet connection], mostly for [#p security] purposes /', ' We [#a collect] [#dt cookies],', ' We [#a use] [#dt cookies] exclusively for [#p authentication purposes].]  /', ' we’ll [#a save] your [#dt carts] and abandoned carts so that just in case something happens, you [#p(save state) don’t lose your order progress]. /', ' [#dt Card data] is [#a(share) sent directly to our payment partners], and is never stored on our servers. Saved cards are [#a(share) stored managed by these partners].]  /'], 'Actions': ['(share) sent directly to our payment partners', '(share) stored by Sendgrid, a Twilio Product', ' collect', ' save', '(process:aggregate) use your data in the aggregate', ' use', ' collecting', ' storing', '(share) stored managed by these partners', ' using'], 'Data Types': [' email', ' Card data', '(contact data) consumer information', ' Spending', ' information regarding your internet connection', '(app interactions) Site Visit Habits', '(app interactions:visit timestamps) how long you visit for', '(personal data) data about you', '(app interactions:clicks) what you click on', ' email address', ' Phone Number', '(app interactions) data about your visit and site habits', ' address', '(app interactions) interact with the site', ' Email', ' Full name', ' IP address', ' spending habits', ' cookies', ' carts', '(spending) card'], 'Purposes': ['(customization) link them to your customer profile', '(analytics:user habits)  prepare appropriately for when they might get busy.', '(analytics) actionable insights in real time to other restaurants and their employees', '  ...
# Results for ai.halloween.aifilter.art\privacy_policy.txt:
# {'Annotations': [], 'Actions': [], 'Data Types': [], 'Purposes': []}
# Results for aiart.midjourney.dreamnow\privacy_policy.txt:
# {'Annotations': [' we [#a collect], [#a use], and protect your [#dt personal information] /', " We may [#a collect] [#dt personal information] that you provide to us when using the App, such as your [#dt name], [#dt email address], and other contact information. b. Usage Information: We may [#a collect] [#dt(app interactions) information about how you use the App], including your [#dt interactions with the App's features and content]. c. Device Information: We may [#a collect] [#dt information about your device], including its [#dt unique device identifier], [#dt IP address], and [#dt operating system]. /", " How We [#a Use] Your Information a. Provide and Improve the App:We [#a use] [#dt your information] to [#p provide and improve the App's functionality] and user experience. b. Communication: We may use your contact information to [#p(contact)+(advertisement) communicate with you about updates, promotions, and other relevant information related to the App]./"], 'Actions': [' collect', ' use', ' Use'], 'Data Types': [' IP address', ' unique device identifier', '(app interactions) information about how you use the App', ' personal information', ' operating system', " interactions with the App's features and content", ' information about your device', ' your information', ' email address', ' name'], 'Purposes': ['(contact)+(advertisement) communicate with you about updates, promotions, and other relevant information related to the App', " provide and improve the App's functionality"]}
# Results for at.tomtasche.reader.pro\privacy_policy.txt:
# {'Annotations': [' the [#a collection], [#a use], and [#a disclosure]\nof [#dt Personal Information] if anyone decided to use my Service. /', ' the [#a collection] and [#a use] of information in\nrelation to this policy. The [#dt Personal Information] that I [#a collect] is used for [#p(functionality) providing and improving\nthe Service]. /', ' Information [#a Collection] and [#a Use]\nFor a better experience, while using our Service, I may [#a(collect) require you to provide us] with certain\n[#dt personally identifiable information]. /', ' The app does [#a(share) use third party services that may collect] [#dt(personal data) information used to identify you.] /', ' [#dt Log Data]\nI want to inform you that whenever you use my Service, [#p(security:system security) in a case of\nan error in the app] I [#a collect] data and information (through third party products) on your phone\ncalled [#dt Log Data]. This [#dt Log Data] may include information such as your device [#dt Internet Protocol (“IP”) address],\n[#dt device name], [#dt operating system version], the configuration of the app when utilizing my Service,\nthe [#dt(timestamps) time and date of your use] of the Service, and other statistics. /', " [#dt Cookies] Cookies are files with a small amount of data that are commonly used as anonymous unique identifiers.\nThese are sent to your browser from the websites that you visit and are stored on your device's internal\nmemory.\nThis Service does not use these “cookies” explicitly.]However, the app may [#a(share) use third party code and\nLibraries use] [#dt “cookies”] to collect information and [#p(functionality) improve their services]. /", ' I may [#a(share) employ third-party companies] and individuals due to the following reasons:\n[#p(functionality) To facilitate our Service];\n[#p(functionality) To provide the Service on our behalf];\n[#p(functionality) To perform Service-related services]; or\n[#p(user habits) To assist us in analyzing how our Service is used].\nI want to inform users of this Service that these third parties have access to\nyour [#dt Personal Information]. /'], 'Actions': [' Collection', ' collect', '(collect) require you to provide us', ' disclosure', '(share) use third party services that may collect', ' use', ' Use', ' collection', '(share) employ third-party companies'], 'Data Types': [' personally identifiable information', ' device name', '(personal data) information used to identify you.', ' operating system version', ' Log Data', ' “cookies”', ' Personal Information', ' Cookies', ' Internet Protocol (“IP”) address', '(timestamps) time and date of your use'], 'Purposes': ['(functionality) To provide the Service on our behalf', '(functionality) improve their services', '(functionality) To perform Service-related services', '(user habits) To assist us in analyzing how our Service is used', '(functionality) To facilitate our Service']}
# Results for bau.moho.freevpn\privacy_policy.txt:
# {'Annotations': [' with the [#a collection], [#a use], and disclosure of [#dt Personal\nInformation] if anyone decided to use our Service.\nIf you choose to use our Service, then you agree to\nthe [#a collection] and [#p use] of information in relation to this\npolicy. The Personal Information that we collect is\nused for [#p providing and improving the Service]. /', ' we\nmay require you to [#a provide us] with certain [#dt personally\nidentifiable information]. /', ' The app does use [#a(Transfer: External) third-party services that may collect\ninformation used to identify you]. /', ' we [#a collect] data and information (through third-party\nproducts) on your phone called [#dt Log Data]. This Log Data may\ninclude information such as your device [#dt Internet Protocol\n(“IP”) address], [#dt device name] , [#dt operating system version], /', ' the app may [#a(transfer) use third-party code and libraries] that use\n[#dt “cookies”] to [#p(functionality) collect information and improve their services] /'], 'Actions': [' provide us', ' collect', ' use', ' collection', '(transfer) use third-party code and libraries'], 'Data Types': [' operating system version', ' Log Data', ' “cookies”', ' device name'], 'Purposes': [' providing and improving the Service', '(functionality) collect information and improve their services', ' use']}
# Results for blizzard.ponderonweather\privacy_policy.txt:
# {'Annotations': [' Our company [#a collects] the following set of data and information:Personal identification information ( [#dt  name],  [#dt physical address],  [#dt email address],  [#dt phone number]…)  [#dt Images],  [#dt videos] /', ' we [#a collect] data and [#a process] [#dt personal data and information] when: [#p(accounts:functionality) You register online] or [#p(order fulfillment:functionality) place and order for any of our products] /', '  [#a(external: collect) Our company might also receive data] /', ' Our company [#a collects] your data so that we can:[#p Process your order], [#p manage your account] [#p Send you email] /', ' processes your [#dt order] it may [#a(transfer) send your data to credit and banking agencies] to [#p prevent fraudulent purchases] /', ' Our company will [#a(timed:delete) keep your [#dt email] and [#dt first name]  for 90 days] /', ' [#dt Device model (anonymous)] [#dt OS version (anonymous)] [#dt(device information)  Device’s language (anonymous)] [#dt(location) Geolocalisation if provided Country (deducted from geolocalisation) City (deducted from geolocalisation)] /', '  [#dt Personal identification information] ([#dt name], [#dt email address], [#dt phone number…)] Also when you visit our website the following information is automatically received and [#a stored by servers]: [#dt IP address] /', ' to [#p contact you], respond to your message or provide information or services you requested. We [#a use] [#dt(personal data) data you provide] and automatically generated data for [#p statistical analysis to assess what information is of interest to users and system performance]. This allows us to make general improvements to our site. We may also [#a use] [#dt your information] in order to [#p detect, prevent and  respond to security issues] /', ' Our company [#a(transfer) uses a third-party analytics provider] (such as Google Analytics) to [#p analyze data from cookies]. /', ' we may [#a(collect) send cookies or other similar tracking technologies] to your computer or to any other device you use. We [#a use] [#dt cookies] and similar [#dt tracking technologies] to [#p(customization) track user’s preferences and to know how he uses our services]. /', ' we [#a use] your [#dt personal information] and data to provide you with [#p targeted advertisements] or [#p marketing] communications we believe may be of interest to you. For example: We [#a(transfer) use Google Analytics] to help us [#p(analytics:user habits) understand how our customers use the Site]. /', ' The [#p advertisements may be personalized] to reflect your interests. To help determine your interests [#a(transfer) Google and its partners  use cookies]. The cookies are used to [#p(analytics:user habits) track your previous visits to our website and your visits to other websites]. /', ' We can [#a use] different type of [#dt cookie] or [#dt tracking technologies] while you are visiting our website and/or application: Strictly necessary cookies: These types of cookies enable you to access and browse websites and use their features. Without these cookies, services like [#p billing or shopping baskets] cannot work properly. Performance cookies: these cookies collect information and data about how you use our websites and/or application. The data collected can be [#a used] to [#p optimize our websites and/or applications]. These [#dt cookies] are [#a used] to [#p(analytics:user habits) know where our visitors and users are coming from.] These cookies do not collect information that identifies you personally. Functionality cookies: these cookies allow our website or application to remember your choices. They can be [#a used] to [#p memorize] your [#dt localisation], /'], 'Actions': ['(transfer) Google and its partners  use cookies', '(timed:delete) keep your [#dt email', '(transfer) uses a third-party analytics provider', ' used', ' collect', ' collects', ' process', ' stored by servers', '(collect) send cookies or other similar tr ...
# Results for bloodpressure.bloodpressureapp.bloodpressuretracker\privacy_policy.txt:
# {'Annotations': [' we [#a collect] [#dt Cookies] ( Webview browser cookies) - When you visit Forum service, we may send one or more cookies files with small amount of data that is commonly used an anonymous [#dt unique identifier to your mobile device] that uniquely identifies your device\nand allows the application to help you [#p log in faster and enhance your navigation through the Forum]. /', ' Our app may [#a(transfer) use some providers] to [#p show ads]. /', ' We [#a use third party analytics tool, Google Analytics,] to help us [#p(analytics:user habits) measure traffic and usage trends] for the service. Google Analytics [#a collects] information such as [#dt(app interactions)  how often users visit our services,] what [#dt(app interactions) pages they visit] [#dt(timestamps) when they do so], /', ' [#a (consent:external:collect) permit us to import [#dt health data] into the App from third-party services such as Google Fit.] Permitting us to access third party information can help you to [#p(functionality) maximize your App experience], /', ' The PII [#a(collect) we may get from you] in that situation are strictly limited to your [#dt name], [#dt email address], [#dt device information], [#dt location Information] and your survey response only. How we use your information In above situation, we guarantee that your PII will only be used for [#p contacting] you and [#p improving our services]. /'], 'Actions': [' use third party analytics tool, Google Analytics,', '(transfer) use some providers', '(collect) we may get from you', ' collect', ' collects', ' (consent:external:collect) permit us to import [#dt health data'], 'Data Types': ['(timestamps) when they do so', ' unique identifier to your mobile device', '(app interactions) pages they visit', ' health data', ' location Information', ' email address', ' device information', ' Cookies', '(app interactions)  how often users visit our services,', ' name'], 'Purposes': [' improving our services', '(analytics:user habits) measure traffic and usage trends', ' contacting', '(functionality) maximize your App experience', ' log in faster and enhance your navigation through the Forum', ' show ads']}
# Results for com.adv.flixgo.movies\privacy_policy.txt:
# {'Annotations': [" MaxPlay Plus Video Player may [#a collect] certain [#dt(personal information) personally identifiable information] from Users in order to [#p(functionality) provide and improve the app's services.] This may include: [#dt Usage Data]: We may collect information on how you use the MaxPlay Plus Video Player app, such as your [#dt(app interactions) interactions with features], [#dt(app interactions) playback history], and preferences. [#dt Device Information]: We may [#a collect] device-specific information, such as the [#dt type of device], [#dt operating system version], and unique [#dt device identifiers]. /", " MaxPlay Plus Video Player [#a (share) integrates the following third-party services], subject to their respective privacy policies: Google Billing SDK: Used for [#p in-app purchases], billing, and subscription management. Google's privacy policy can be found at:\nhttps://policies.google.com/privacy Firebase SDK: Used for [#p analytics], crash reporting, and [#p(analytics) performance monitoring]. /", ' We may [#a share] your information with third parties under the following circumstances: With your Consent: We may [#a share] your information with third parties if you give us consent to do so. For [#p(compliance:legal compliance) Legal Reasons]: We may [#a disclose] your information to [#p(compliance:legal compliance) comply with applicable laws, regulations, legal processes, or enforceable governmental requests]. /'], 'Actions': [' share', ' (share) integrates the following third-party services', ' collect', ' disclose'], 'Data Types': [' Device Information', '(personal information) personally identifiable information', ' Usage Data', ' operating system version', '(app interactions) playback history', ' type of device', '(app interactions) interactions with features', ' device identifiers'], 'Purposes': [' analytics', '(compliance:legal compliance) Legal Reasons', ' in-app purchases', '(compliance:legal compliance) comply with applicable laws, regulations, legal processes, or enforceable governmental requests', '(analytics) performance monitoring', "(functionality) provide and improve the app's services."]}
# Results for com.aisecurity\privacy_policy.txt:
# {'Annotations': [" Types of Data [#a Collected]\n[#dt Personal Data]\nWhile using Our Service, We may ask You to provide Us with certain [#dt personally identifiable information] that can be [#a used] to [#p contact] or [#p identify] You. Personally identifiable information may include, but is not limited to:\n[#dt Usage Data]\n[#dt Usage Data]\n[#dt Usage Data] is [#a collected automatically] when using the Service.\n[#dt Usage Data] may include information such as Your Device's [#dt Internet Protocol address] (e.g. [#dt IP address]), [#dt browser type], browser version, the [#dt(app interactions) pages of our Service that You visit], the [#dt(timestamps) time and date of Your visit], the [#dt(timestamps) time spent on those pages], [#dt unique device identifiers] and other [#dt diagnostic data]. /", ' When You access the Service by or through a mobile device, We may [#a collect] certain information automatically, including, but not limited to, the [#dt type of mobile device] You use, Your mobile device [#dt unique ID], the [#dt IP address] of Your mobile device, Your mobile [#dt operating system], the type of mobile Internet browser You use, [#dt unique device identifiers] and other [#dt diagnostic data].\nWe may also [#a collect] [#dt(usage data) information that Your browser sends] whenever You visit our Service or when You access the Service by or through a mobile device. /', ' [#a Use] of Your [#dt Personal Data]\nThe Company may [#a use] ]#dt Personal Data] for the following purposes:\n[#p(functionality) To provide and maintain our Service] , including to [#p(user habits) monitor the usage of our Service].\n[#p(account management) To manage Your Account]:\nto manage Your registration as a user of the Service. The [#dt Personal Data] You provide can [#p(access) give You access to different functionalities] of the Service that are available to You as a registered user. \n[#p(order fulfillment) For the performance of a contract:]\nthe development, compliance and undertaking of the purchase contract for the products, items or services You have purchased or of any other contract with Us through the Service.\n[#p To contact You:] /', ' [#p To contact You] by [#dt email], [#dt telephone] calls, [#dt SMS], /', ' To provide You\nwith news, [#p(personalized:advertisement) special offers and general information about other goods, services and events which we offer that are similar to those that you have already purchased or enquired about] unless [#a(revoke:consent) You have opted not to receive such information] /', ' We may [#a use] [#dt Your information] for other purposes, such as [#p data analysis], [#p(user habits) identifying usage trends], [#p(marketing effectiveness)  the effectiveness of our promotional campaigns and to evaluate and improve our Service], /', ' We may [#a share] Your [#dt personal information] in the following situations:\nWith Service Providers:\nWe may share Your personal information with Service Providers to [#p(user habits) monitor and analyze the use of our Service], to [#p contact You.] /', ' We may [#a share] or transfer Your [#dt personal information] [#p(sale:requirements) in connection with, or during negotiations of, any merger, sale of Company assets, financing, or acquisition /', ' We may [#a share] [#dt Your information] with Our business partners [#p(advertisement) to offer You certain products, services or promotions.] /', ' The Company will [#a retain] Your [#dt Personal Data] only for as long as is necessary for the purposes set out in this Privacy Policy. We will [#a retain] and [#a use] Your [#dt Personal Data] to the extent necessary [#p(legal compliance) to comply with our legal obligations] /', ' The Company will also [#a retain] [#dt Usage Data] for [#p internal analysis] purposes. [#dt Usage Data] is generally retained for a shorter period of time, except when this data is used to strengthen the [#p security] or to improve the [#p functionality] of Our Service, or [#p(legal compli ...
# Results for Com.app.mmallbooks\privacy_policy.txt:
# {'Annotations': [' The [#dt Personal Information] that I [#a collect] is used for [#p(functionality) providing and improving the Service]. /', ' I may [#a(collect) require you to provide us with certain personally identifiable information, including but not limited to Pro Learner, [#dt Name] – Mr. Wai Yan. Personal identification numbers: [#dt driver’s license number]- 678904567345. [#dt Contact email] – prolearn77@gmail.com, Contact Address – 289 番地\u30001 サﾝグローブ\u3000II 401, Uruma-shi, Okinawa, Japan. . The information that I request will be retained on your device and is not collected by me in any way.\nThe app does [#a use third-party services] that may collect information used [#p(indentification)  to identify you.] /', ' I [#a collect] data and information (through third-party products) on your phone called [#dt Log Data]. This [#dt Log Data]. may include information such as your [#dt device Internet Protocol (“IP”) address],  the configuration of the app when utilizing my Service, the time a[#dt device name], [#dt operating system version,] and [#dt(app interactions:visit timestamps) date of your use of the Service], and other statistics. /', ' the app may [#a use third-party code] and libraries that use [#dt “cookies”] to [#a collect] information and [#p improve their services.] /', ' I may  [#a(share) employ third-party companies] and individuals due to the following reasons:\n[#p To facilitate our Service;]\n[#p To provide the Service on our behalf;]\nTo perform Service-related services; or\n[#p To assist us in analyzing how our Service is used.]\nI want to inform users of this Service that these [#a(share) third parties have access] to their [#dt Personal Information]. /'], 'Actions': [' collect', ' use third-party code', '(collect) require you to provide us with certain personally identifiable information, including but not limited to Pro Learner, [#dt Name', ' use third-party services', '(share) third parties have access', '(share) employ third-party companies'], 'Data Types': [' operating system version,', ' device Internet Protocol (“IP”) address', ' “cookies”', ' Log Data', ' Personal Information', ' driver’s license number', ' Name', '(app interactions:visit timestamps) date of your use of the Service', ' device name', ' Contact email'], 'Purposes': ['(functionality) providing and improving the Service', ' To facilitate our Service;', '(indentification)  to identify you.', ' To assist us in analyzing how our Service is used.', ' To provide the Service on our behalf;', ' improve their services.']}
# Results for Com.app.mypersonalweathermanapp\privacy_policy.txt:
# {'Annotations': [' We may [# a collect] the following information:\nFor the [#p(functionality) chat feature to work] properly in your messenger app, we will need to access the [#dt contact list] of app users.\n[#dt name] and [job title]\ncontact information including [#dt email address]\ndemographic information such as [#dt postcode], /', ' What information do you [#a collect] - This includes both information entered by the user i.e. [#dt profile pic], [#dt phone number], [#dt name], etc or information which is collected automatically i.e. HTTP logs, data usage or anything in the background.\nAll user data [#a(collected: stored) uploaded into our system], including users’ [#dt Image information] in the mobile app, is [#a stored] in a personalized and secure location. /', ' We may [#a use] the information to [#p improve our products and services.]\nWe may periodically send [#p(advertisement:personalized) promotional emails about new products], special offers or other information which we think you may find interesting using the email address which you have provided.\nFrom time to time, we may also use your information to [#p(analytics) contact you for market research] purposes. We may [#p contact you] by email, phone, fax or mail. We may use the information to [#p customise the App] according to your interests. /', ' We [#a use] [#dt traffic log cookies] to [#p(analytics:user habits) identify which pages are being used]. /', ' We [#a use] [#dt your data] to [#p provide and improve the Service]. /', ' Types of Data [#a Collected]\n[#dt Personal Data]\nWhile using our Service, we may ask you to provide us with certain personally identifiable information that can be used to contact or identify you ("Personal Data"). Personally identifiable information may include, but is not limited to:\n[#dt Email address]\n[#dt First name and last name]\n[#dt Phone number]\n[#dt Address, State, Province, ZIP/Postal code, City]\nCookies and Usage Data\nWe may use your Personal Data to [#p(advertisements) contact you with newsletters, marketing or promotional materials] /', ' [#dt Usage Data]\nWe may also [#a collect] information how the Service is accessed and used ("Usage Data"). This Usage Data may include information such as your computer\'s [# dt Internet Protocol address] (e.g. IP address), [#dt browser type], browser version, the [#dt(app interactions) pages of our Service that you visit], the [#dt(app interaction:visit timestamps) time and date of your visit, the time spent on those pages], [#dt unique device identifiers] and other diagnostic data. /', ' [#dt Tracking & Cookies] Data\nWe [#a use] [#dt cookies] and similar [#dt tracking technologies] to [#p(analytics) track the activity on our Service] and hold certain information./', ' we [#a use:]\n[#dt Session Cookies]. We [#a use] [#dt Session Cookies] to [#p operate our Service]. /', ' [#dt Preference Cookies]. We [#a use] [#dt Preference Cookies] to [#p(customization:memorization) remember your preferences and various settings.] /', ' [#dt Security Cookies]. We [#a use] [#dt Security Cookies] for [#p security purposes.] /', ' [#dt Advertising Cookies] [#dt Advertising Cookies] are [#a used] to serve you with [#p advertisements that may be relevant to you and your interests.] /', ' My Personal Weatherman [#a uses] the [#dt(personal data) collected data[ for various purposes:\n[#p(functionality) To provide and maintain our Service]\n[#p(contact) To notify you about changes to our Service]\nTo allow you to participate in interactive features of our Service when you choose to do so\nTo provide customer support\n[#p(analytics) To gather analysis or valuable information so that we can improve our Service]\n[#p(analytics) To monitor the usage of our Service]\nTo detect, prevent and address technical issues\n[#p(marketing To provide you with news, special offers and general information about other goods,] /', ' My Personal Weatherman will also [#a retain] [#dt Usage Data] for [#p internal ana ...
# Results for com.appvision.babygenerator.android\privacy_policy.txt:
# {'Annotations': [' The app does [#a use third-party services]  that may [#a collect] information used to [#p(identification) identify you]. /', ' We [#a collect] data and information (through third-party products) on your phone called [#dt Log Data]. This [#dt Log Data] may include information such as your device [#dt Internet Protocol (“IP”) address], [#dt device name], [#dt operating system version], the configuration of the app when utilizing my Service, the [#dt(app interactions:visit timestamps) time and date of your use of the Service,] /', ' the app may [#a use third-party] code and libraries that use [#dt “cookies”] to [#a collect] information and [#p(analytics) improve their services]. /', ' these [#a(share) third parties have access] to their [#dt Personal Information.] /'], 'Actions': [' collect', ' use third-party', '(share) third parties have access', ' use third-party services'], 'Data Types': [' Internet Protocol (“IP”) address', ' operating system version', ' “cookies”', ' Log Data', ' Personal Information.', '(app interactions:visit timestamps) time and date of your use of the Service,', ' device name'], 'Purposes': ['(analytics) improve their services', '(identification) identify you']}
# Results for com.banix.drawsketch.ardraw\privacy_policy.txt:
# {'Annotations': [' which governs our [#a collection] and [#a use] of [#dt your information], which may include [#dt personal data]. As part of our provision of the Service, we may need to [#p(communication) provide you with certain communications], /'], 'Actions': [' collection', ' use'], 'Data Types': [' your information', ' personal data'], 'Purposes': ['(communication) provide you with certain communications']}
# Results for com.brandemaker.dailypost\privacy_policy.txt:
# {'Annotations': [' the [#a collection], [#a use], and [#a disclosure] of [#dt Personal Information] /', ' The [#dt Personal Information]\n that I [#a collect] is [#a used] for [#p(app functionality) providing and improving the Service]. /', ' Information [#a Collection] and [#a Use] For a [#p(functionality) better experience], while using our Service, I may [#a require you to provide us] with certain [#dt personally identifiable information]. /', ' The app does [#a(share) use third party services that may collect] information used to [#p identify you]. /', '  [#dt Log Data] I want to inform you that whenever you use my Service, [#p(site protection) in a case of an error] in the app I [#a collect] data and information (through third party products) on your phone called [#dt Log Data]. This Log Data may include information such as your device [#dt Internet Protocol (“IP”) address], [#dt device name], [#dt operating system] version, the configuration of the app when utilizing my Service, the [#dt( timestamps) time and date of your use] /', ' the app may [#a use third party] code and libraries that use [#dt “cookies”] to [#p( analytics) collect information] and [#p(functionality) improve their services]. /', ' I may [#a(share) employ third-party] companies and individuals due to the following reasons: [#p(functionality) To facilitate our Service; To provide the Service on our behalf; To perform Service-related services]; or To assist us in [#p(analytics) analyzing how our Service is used]. I want to inform users of this Service that these third parties have access to your [#dt Personal Information]. /'], 'Actions': [' use third party', ' Collection', '(share) employ third-party', ' used', ' collect', ' disclosure', '(share) use third party services that may collect', ' use', ' Use', ' collection', ' require you to provide us'], 'Data Types': ['( timestamps) time and date of your use', ' personally identifiable information', ' Internet Protocol (“IP”) address', ' “cookies”', ' Log Data', ' operating system', ' Personal Information', ' device name'], 'Purposes': ['(app functionality) providing and improving the Service', '(functionality) To facilitate our Service; To provide the Service on our behalf; To perform Service-related services', '(functionality) better experience', ' identify you', '(functionality) improve their services', '(site protection) in a case of an error', '(analytics) analyzing how our Service is used', '( analytics) collect information']}
# Results for com.charstar.andoid\privacy_policy.txt:
# {'Annotations': [' We [#a use] Your [#dt Personal data] to [#p(functionality) provide and improve the Service]. By using the Service, You agree to the [#a collection] and [#a use] of information in accordance with this Privacy Policy. /', " [#a Collecting] and [#a Using] Your [#dt Personal Data]\nTypes of Data [#a Collected]\n[#dt Personal Data]\nWhile using Our Service, We may [#a(collect) ask You to provide Us] with certain [#dt personally identifiable information] that can be used to contact or identify You. Personally identifiable information may include, but is not limited to:\n[#dt Email address]\n[#dt Phone number]\n[#dt Usage Data]\n Usage Data\n Usage Data is [#a collected automatically] when using the Service.\n[#dt Usage Data] may include information such as Your Device's [#dt Internet Protocol address] (e.g. {#dt IP address]), [#dt browser type], [#dt browser version], the [#dt(usage data:app interactions) pages of our Service that You visit], the [#dt(usage data: app interactions: visit timestamps) time and date of Your visit], the [#dt(usage data: app interactions: visit timestamps) time spent on those pages], unique [#dt device identifiers] and other [#dt diagnostic data.]\nWhen You access the Service by or through a mobile device, We may [#a collect] certain information automatically, including, but not limited to, the [#dt type of mobile device] You use, Your mobile device [#dt unique ID], the [#dt IP address] of Your mobile device, Your mobile [#dt operating system], the type of mobile Internet [#dt browser] You use, unique [#dt device identifiers] and other [#dt diagnostic data].\nWe may also [#a collect] [#dt(usage data) information that Your browser sends] whenever You visit our Service or when You access the Service by or through a mobile device. /", ' [#dt Tracking Technologies] and [#dt Cookies]\nWe [#a use] [#dt Cookies] and similar [#dt tracking technologies] to [#p(analytics:user habits) track the activity on Our Service] and [#a store] certain information. [#dt Tracking technologies] [#a used] are [#dt beacons], [#dt tags], and scripts to [#a collect] and track information and to [#p(analytics) improve and analyze Our Service]. The technologies We use may include:\n[#dt Cookies] or [#dt Browser Cookies.] /', ' We [#a use] both Session and Persistent [#dt Cookies] for the purposes set out below:\nNecessary / Essential Cookies\nType: [#dt Session Cookies]\nAdministered by: Us\nPurpose: These Cookies are essential to [#p(functionality) provide You with services] available through the Website and to [#p(functionality) enable You to use some of its features]. They help to [#p(identify) authenticate users] and [#p(security:user security) prevent fraudulent use of user accounts]. /', ' Type: [#dt Persistent Cookies]\nAdministered by: Us\nPurpose: These Cookies allow us to [#p(customization:memorization) remember choices You make when You use the Website], such as remembering your login details or language preference. The purpose of these Cookies is to [#p(customization) provide You with a more personal experience] /', ' [#a Use] of Your [#dt Personal Data]\nThe Company may [#a use] [#dt Personal Data] for the following purposes:\nTo [#p(functionality) provide and maintain our Service] , including to [#p(analytics:user habits) monitor the usage of our Service.]\n[#p(accounts) To manage Your Account:]\nto manage Your registration as a user of the Service. The Personal Data You provide can give You [#p(functionality:access) access to different functionalities of the Service] /', ' To [#p contact] You:\nTo [#p contact] You by [#dt email], [#dt telephone calls], /', ' To provide You\nwith news, [#p(advertisement:personalized) special offers and general information about other goods, services and events which we offer that are similar to those that you have already purchased or enquired] about /', ' We may [#a use] [#dt Your information] for other purposes, such as [#p(analytics) data analysis], [#p(analytics: u ...
# Results for com.chula.app\privacy_policy.txt:
# {'Annotations': [' [#a collection] and [#a use] of your [#dt personal information.] We [#a collect] [#dt personal information] including [#dt name], [#dt physical address], [#dt phone number], [#dt card information], technical data and related information, and your [#dt current location] to [#p(functionality) better your use of the Service with more accuracy.] We [#a collect] this information via direct interactions as you use our website. Chula, LLC does not sell your personal information to the third party but we may use it for [#p(analytics) surveys], [#p(advertisement) contests, promotions] or other programs,manage and execute delivery services, provide customer support and [#p(contact) respond to your inquiries], [#p(security) protect against and prevent fraud, unauthorized transactions, claims and other liabilities]. /'], 'Actions': [' collection', ' collect', ' use'], 'Data Types': [' personal information.', ' current location', ' phone number', ' personal information', ' physical address', ' card information', ' name'], 'Purposes': ['(functionality) better your use of the Service with more accuracy.', '(advertisement) contests, promotions', '(analytics) surveys', '(security) protect against and prevent fraud, unauthorized transactions, claims and other liabilities', '(contact) respond to your inquiries']}
# Results for com.cigna.mobile.mycigna\privacy_policy.txt:
# ...
# Results for de.twokit.video.tv.cast.browser.lg.pro\privacy_policy.txt:
# {'Annotations': [' purposes:\n[#p(contact:support) Customer Support]\nProduct Improvement\nFuture Product Development\n[#p Security, Safety, and Dispute Resolution]\n[#p(analytics) Product Performance Analysis]\n[#p Communications and Product Announcements] /', ' What kind of data we [#a collect]\nWe [#a collect] the following kinds of data:\n[#dt Personal information]\n[#dt Name]\n[#dt Email address]\n[#dt Location data]\n[#dt IP address]\n[#dt(social media accounts details) Social identifiers (e.g. Twitter or Facebook user IDs)]\n[#dt Mobile device model], brand and [#dt operating systems]\nStreaming device model, brand and firmware\n[#dt Payment information] (e.g. anonymized payment IDs)\nNon-personal information\nApp Performance information: e.g. anonymized crash information to help us identify errors and improve the app and services.\n[#dt App Activity] information: e.g. general [#dt(app interactions) app usage indicators], specific [#dt(app interactions) usage events in the app], anonymized data about the videos which are streamed by the app, either successfully or with error, including information about websites containing the video.\nWebsite Activity information: Anonymized [#dt(app interactions) usage statistic data] to [#p improve the Website] and for [#p(analytics) business analytics purposes.] /', ' 2) [#a Automatic data collection] in the App\n[#p(user habits) Usage Tracking]: We [#a(share) use industry standard Google Analytics tracking] for the purposes described in section “Why we collect data”. During first start of the App, [#a(request:consent) you will be prompted to give your consent to this privacy policy], including usage tracking. Afterwards [#a(revoke:consent) you can opt-out of collecting non-personally-identifying analytics data at any time in the App Settings -> Diagnostics & Usage]. /', ' We [#a use] [#dt cookies] to [#p personalize content], to be able to offer functions for social media and to [#p(user habits) analyse access to our websites]. We also [#a share] [#dt(anonymized:user habits)  anonymized information about your use of our websites] with our social media and analytics partners. /', ' We [#a(share) use third-party providers] to carry out [#p(functionality) services like website and email hosting]. [#dt Personal information] may be stored by these providers for fulfilling the service, for example your [#dt email address] may be stored by our email provider. /', ' TV or streaming service providers: We may [#a share] [#dt personal information] with TV or streaming service providers like Google, Samsung or LG to enable video casting on third party devices like TVs or streaming players. For example the current [#dt IP address] of your mobile device is needed to connect your mobile phone or tablet to the TV or streaming device. /'], 'Actions': [' share', '(share) use industry standard Google Analytics tracking', ' collect', '(share) use third-party providers', ' Automatic data collection', ' use', '(revoke:consent) you can opt-out of collecting non-personally-identifying analytics data at any time in the App Settings -> Diagnostics & Usage', '(request:consent) you will be prompted to give your consent to this privacy policy'], 'Data Types': ['(app interactions) app usage indicators', ' operating systems', ' cookies', '(anonymized:user habits)  anonymized information about your use of our websites', ' Email address', ' personal information', ' Personal information', '(app interactions) usage events in the app', ' App Activity', ' Mobile device model', ' Payment information', ' Name', '(app interactions) usage statistic data', ' email address', '(social media accounts details) Social identifiers (e.g. Twitter or Facebook user IDs)', ' IP address', ' Location data'], 'Purposes': [' personalize content', '(functionality) services like website and email hosting', ' Communications and Product Announcements', '(analytics) Product Performance Analysis', '(contact:support) Customer Support', ' Securit ...
# Results for ee.mtakso.client\privacy_policy.txt:
# {'Annotations': [' [#dt Personal data] we [#a process]\nWe only [#a process] information that we need, so that we can provide you with the best service on our transportation marketplace. The data categories are as follows:\n[#dt Contact details] : things like [#dt name], [#dt phone number] and [#dt e-mail address]. For some of our services we might require a little more, like your [#dt home address].\nProfile information : things like your [#dt profile picture], saved addresses, language and communication preferences. For some of our services we might require a little more, like your [#dt driver license details].\n[#dt Geolocation] : such as where you need a ride from, or the location of nearby scooters to you, the time, the journey progression and the final destination of your trip.\n[#dt Payment information]\nlike the [#dt(spending info) amount charged] and the [#dt payment card] used.\n[#dt(account information: messages) Communication and correspondence records]\nsuch as when you engage with our in-app chat, or speak with our customer service agents.\nLimited identification data of the device , like the [#dt IP address], on which the Bolt app has been installed\nData about the usage of the transportation services : things like [#dt(transportation data) data about journey status], times and data about your conduct as assessed by drivers.\nData on sensors for rental vehicles . It contains information such as [#dt(transportation data) vehicle speed, engine power, driving style information] (including sudden braking or skidding) and the total weight of objects and person(s) on the vehicle and changes in the weight. /', ' we [#a collect] and [#a process] the [#dt personal data] submitted by you in the course of installing and using the Bolt app; refusing to share [#dt geolocation] data via the App means we cannot [#p(functionality:access) direct a driver to your location for pick-up, nor can we show you one of our own vehicles close to you for hire] \\', ' We [#a process] your [#dt personal data] so we can [#p(functionality:access) provide you with one or more of our transportation services]:\nWe connect you with a driver, help find you a scooter or hire a vehicle : We [#a collect] and [#a process] [#dt personal data] for the purpose of [#p(functionality:order fulfillment:localization) connecting passengers with drivers so you can be picked up and dropped off]; or to [#p(functionality:localization) show you where our nearest available hire-vehicles are located], such as our cars or scooters. [#dt(account info:messages) Instant messages directly in the Bolt app] are [#a processed] in order to [#p(contact:support) provide service and customer support] (including resolving disputes between driver and rider), for [#p security purposes] as well as to improve our products and services, and for [#p analysis]. /', " [#a collection] of [#dt geolocation data] [#a(collect:stop) stops after closing the Bolt app]. In some countries drivers cannot see passengers' phone numbers; the driver sees an altogether different number which temporarily diverts to the passenger's phone number meaning the driver and passenger can still communicate.\nWe make sure your journey goes smoothly : We [#a use] [#dt geolocation] data to [#p(functionality:order fulfillment:localization) make sure you get to your destination] /", ' We [#a use] [#dt contact details] to [#p(contact) notify passengers and riders of updates to the Bolt app] /', ' We also [#a(collect) gather] limited [#dt(usage data)  data from the device] that you use to connect you with our internet, mobile and telephone services, and to help keep your account safe through [#p(identification) authentication and verification checks.] /', ' We [#a collect] [#dt(localization) data on the routes taken by our passengers and riders] to [#p(analytics:system analysis) analyse geographic coverage.] /', ' We [#a collect] your payment : We obtain [#dt payment details] to process passenger payment [#p(functionalit ...
# Results for psplay.grill.com\privacy_policy.txt:
# {'Annotations': [' The [#dt Personal Information] that we [#a collect] is used for [#p(functionality) providing and improving the\nService] (e.g. [#dt log files] for [#p finding errors]). /', ' we may [#a(collect) require you to provide us] with certain\n[#dt personally identifiable information]. The information that we request is will be retained by us and used as described in this privacy policy.\nThe app does [#a(share) use third party services] that may collect information used to identify you./', ' [#dt Log Data]\nWe want to inform you that whenever you use our Service, in a case of an\nerror in the app we [#a collect] data and information (through third party products) on your phone\ncalled [#dt Log Data]. This Log Data may include information such as your device [#dt Internet Protocol (“IP”) address],\ndevice name, [#dt operating system version], the configuration of the app when utilizing our Service,\nthe [#dt(timestamps) time and date of your use of the Service], and other statistics. [#dt Log Data] are only stored on your device. /', ' We may [#a(share) employ third-party companies] and individuals due to the following reasons:\n[#p(functionality) To facilitate our Service;\nTo provide the Service on our behalf;\nTo perform Service-related services]; or\n[#p(analytics) To assist us in analyzing how our Service is used.] /'], 'Actions': ['(share) use third party services', '(share) employ third-party companies', ' collect', '(collect) require you to provide us'], 'Data Types': [' personally identifiable information', '(timestamps) time and date of your use of the Service', ' operating system version', ' Log Data', ' Personal Information', ' Internet Protocol (“IP”) address', ' log files'], 'Purposes': ['(analytics) To assist us in analyzing how our Service is used.', ' finding errors']}
# Results for stepcounter.pedometer.stepstracker\privacy_policy.txt:
# {'Annotations': [' We [#a use] Your [#dt Personal data] to [#p provide] and improve the Service. By using the Service, you agree to the collection and use of information in accordance with this Privacy Policy. /', ' How we [#a Collect] and [#a Use] Your [#dt Personal Data]\n[#dt Personal Data]\nWhile using Our Service through logging in with your social media account , We may ask You to provide Us with certain [#dt personally identifiable information] that can be used to [#p contact] or [#p identify You], including:\n[#dt Email address]\n[#dt First name] and [#dt last name]\n[#dt Usage Data], such as step data\nIn order to provide a better user experience, we require the following information from you:\n[#dt Age]\n[#dt Gender]\n[#dt Weight]\n[#dt Height] /', ' [#dt Log Data]\nWe want to inform you that whenever you use our Service, in case of an [#p error] in the app we [#a collect] data and information (through third party products, such as Google Analytics) on your phone called [#dt Log Data]. This Log Data may include information such as your device [#dt Internet Protocol (“IP”) address], [#dt device name], [#dt operating system] version, the configuration of the app when utilizing my Service, the [#dt(timestamps) time and date of your use of the Service], /', ' Health Kit - You will also have an option to permit us to import [#dt health data] into Google Fit from our app. Permitting us to access third party information can help you to maximize your App experience, and we will handle any such third-party information in accordance with this Privacy Policy.\nPhysical activity Permission -\nwhen you use the pedometer feature in our app, we need permission to access your [#dt Physical Activity] to count your step data.\n[#dt Location] Permission - when you use the pedometer feature in our app, we need this [#p(functionality) permission to count your steps.] /', " The Company allows You to [#p(accounts) create an account] and log in to use the Service through the following Third-party Social Media Services:\nGoogle\nIf You decide to register through or otherwise grant us access to a Third-Party Social Media Service, We may [#a collect] [#dt Personal data] that is already associated with Your Third-Party [#dt Social Media Service's account], such as [#dt Your name], Your [#dt email address], Your activities or Your [#dt contact list] associated with that account. /", ' The Company will [#a retain] [#dt Usage Data] for [#p internal analysis] purposes. Usage Data is generally retained for a shorter period of time, except when this data is used to strengthen the [#p security] or to improve the [#p functionality] of Our Service, or We are [#p(legal compliance) legally obligated] to retain this data for longer time periods. /', ' Under certain circumstances, the Company may be required to [#a disclose] Your [#dt Personal Data] if [#p(legal compliance) required to do so by law] or in response to valid requests by public authorities (e.g. a court or a government agency).\nOther legal requirements\nThe Company may [#a disclose] Your [#dt Personal Data] in the good faith belief that such action is necessary to [#p(legal compliance) Comply with a legal obligation] or Protect and defend the rights or property of the Company. /', " Google AdSense & DoubleClick Cookie\n[#a(share) Google, as a third party vendor], uses [#dt cookies] [#p(advertisement) to serve ads on our Service]. Google's use of the DoubleClick cookie enables it and its partners to serve ads to our users based on their visit to our Service or other websites on the Internet. /", ' You have the right to [#a(revoke:consent) withdraw Your consent] on [#a using] your [#dt Personal Data]. If You withdraw Your consent, We may not be able to provide You with access to certain specific functionalities of the Service. /', ' You also have the right to request the [#a deletion] of Your [#dt Personal Data] that have been collected in the past 12 months./'], 'Actions': [' deletion', ' Coll ...

# %%
# Now we will combine the related actions data types and purposes within each #s 

# There will be connections between all unique entities within each #s 

# And fill out template under conditions of valid stories 

# And display graphs for each connection 


# Initialize a dictionary to hold grouped annotations for each file
grouped_annotations_by_file = {}

# Iterate through the annotations_results dictionary
for file_name, results in annotations_results.items():
    grouped_annotations = []
    for annotation in results['Annotations']:
        # Splitting each annotation into individual elements
        # Assuming each element is separated by a space or some delimiter
        elements = annotation.split()  # Modify this if a different delimiter is used
        grouped_annotations.append(annotation)
    
    # Store the grouped annotations for this file
    grouped_annotations_by_file[file_name] = grouped_annotations

# Now, grouped_annotations_by_file contains grouped annotations for each file
for file_name, grouped_annotations in grouped_annotations_by_file.items():
    print(f"Groups for {file_name}:")
    for group in grouped_annotations:
        print(group)
    print("\n") 

# This list represents the privacy stories which are fully present in individual annotation
def generate_type_1_story(grouped_annotations_by_file):
    sentences_by_file = {}

    for file_name, grouped_annotations in grouped_annotations_by_file.items():
        unique_sentences = set()  # Use a set to store unique sentences
        for group in grouped_annotations:
            # Extract individual actions, data types, and purposes
            actions = re.findall(r'\[\#a(.*?)\]', group)
            data_types = re.findall(r'\[\#dt(.*?)\]', group)
            purposes = re.findall(r'\[\#p(.*?)\]', group)

            # Create sentences for each combination of action, data type, and purpose
            for action in actions:
                for data_type in data_types:
                    for purpose in purposes:
                        sentence = f"We {action.strip()} {data_type.strip()} for the purpose of {purpose.strip()}."
                        unique_sentences.add(sentence)  # Add sentence to the set

        sentences_by_file[file_name] = list(unique_sentences)  # Convert set back to list

    return sentences_by_file

type_1_stories = generate_type_1_story(grouped_annotations_by_file)


def build_annotations(grouped_annotations_by_file):
    all_a = {}
    all_dt = {}
    all_p = {}

    for file_name, grouped_annotations in grouped_annotations_by_file.items():
        a = {}
        dt = {}
        p = {}
        print(f"File: {file_name}")

        for i, group in enumerate(grouped_annotations):
            # Extract individual actions, data types, and purposes within the annotation
            actions = re.findall(r'\[\#a(.*?)\]', group)
            a[i] = [action.strip() for action in actions]
            data_types = re.findall(r'\[\#dt(.*?)\]', group)
            dt[i] = [data_type.strip() for data_type in data_types]
            purposes = re.findall(r'\[\#p(.*?)\]', group)
            p[i] = [purpose.strip() for purpose in purposes]

            # Printing the elements of the current annotation
            print(f"\nAnnotation {i+1}:")
            print("Actions:", a[i])
            print("Data Types:", dt[i])
            print("Purposes:", p[i])

        all_a[file_name] = a
        all_dt[file_name] = dt
        all_p[file_name] = p
        print("\n")  

    return all_a, all_dt, all_p

all_a, all_dt, all_p = build_annotations(grouped_annotations_by_file)

def group_annotations_by_index(all_a, all_dt, all_p):
    grouped_annotations = {}

    for file_name in all_a.keys():
        grouped_file_annotations = []

        num_annotations = len(all_a[file_name])

        for i in range(num_annotations):
            annotation_group = {
                'actions': all_a[file_name].get(i, []),
                'data_types': all_dt[file_name].get(i, []),
                'purposes': all_p[file_name].get(i, [])
            }
            grouped_file_annotations.append(annotation_group)

        grouped_annotations[file_name] = grouped_file_annotations

    return grouped_annotations


# Now, 'grouped_annotations_by_file' contains the grouped annotations per file.\
# file_name = 'your_file_name_here'
# annotations_for_file = grouped_annotations_by_file.get(file_name, [])
# Out:
# Groups for afmstudio.craigslistclassifiedslocal\privacy_policy.txt:
#  We [#a collect] [#dt personal information] to [#p provide and enhance our Services]./
#  we [#a collect] and how we obtain it. 2.1 Information Provided by You During your registration or use of our Services, you may voluntarily provide the following personal information: [#dt Email address] [#dt Mobile telephone number] [# dt Geographic location] [#dt Profile picture] [#dt User ID]  [#dt Facebook] or [#dt Google account details] [#dt Driver's license] or other [#dt government ID] /
#  Information [#a Collected] Automatically When you interact with our Platform or use our Services, we automatically [#a collect] the following information about you: [#dt Device Information:][#dt Operating system version], [#dt device make and model], [#dt and mobile network details]. [#dt Location Information]: Depending on permissions, we may collect [#dt  location data] using methods like [#dt IP address], [#dt GPS],[#dt  Wi-Fi access points], and [#dt mobile towers]. Client and Log Data: Technical details like [#dt IP address], [#dt time zone], [#dt operating system], [#dt login information], and [#dt browser type]. Usage Information: Details of your [#dt activity on our Platform], including [#dt visit timestamps], [#dt clicked advertisements], [#dt interaction with ads], [#dt duration of visits], and [#dt content viewing order]. /
#  Cookies: If you access Services through a web browser, we [#a use] [#dt cookies] for [#p session management], [#p storing preferences], language selection, and [#p targeted advertising]. /
#  We may [#a(external:collect) collect [#dt personal information] from third-party sources]. For instance, we use third-party machine learning software to [#p analyze communications] in our chat feature to [#p prevent fraud and block spam or abusive messages] /
#  is [#a  stored] as [#dt chat messages]. /
#  [#p Identifying] you as a user and providing access to your account settings. Making [#p suggestions and recommendations] about our Services. Offering [#p tailored content] and improving your experience on the Platform. [#p Monitoring campaign effectiveness] and [#p preventing repetitive display of items]. Enhancing performance, [#p personalizing content], and [#p measuring interactions with advertisements]. 3.2 Safety and Security Administering and protecting our Platform, including troubleshooting, data analysis, and fraud prevention. [#p Analyzing communications] in chat for [#p safety and blocking abusive messages]. SMS verification of your telephone number to increase trust and safety. 3.3 Other Purposes Aggregating or de-identifying data for analysis, [#p segmentation], and [#p development of anonymous profiles]. /
#  We may [#a share] your [#dt personal information] with the following parties: [#p Corporate affiliates] [#p Third-party vendors] and service providers [#p Advertisers] [#p Analytics providers] [#p Law enforcement authorities], [#p regulators], [#p courts], and [#p government bodies] [#p Business transfer] /
#  We may [#p communicate with you via email or in-app notifications] related to our Services, including registration confirmations and transactional messages. We may also [#p(advertisement) send you marketing communications] about our Services /
#
#
# Groups for ai.appfront.luckyslice\privacy_policy.txt:
#  INCLUDING TO THE [#a COLLECTION] AND
# [#a PROCESSING] OF YOUR [#dt PERSONAL INFORMATION] /
#  We may [#a collect] two types of data
# and information from our Users:
# a.
# The first type of information is non-identifiable
# and anonymous information ( " [#dt Non-personal
# Information] " ). /
#  [#dt Non-personal Information] which is being [#a (collected) gathered] consists
# of technical information and behavioral information, and may contain, among
# other things, [#dt type of mobile device] and [#dt operating system], number of stamps,
# [#dt places users have stamped], etc. We also collect Non-personal Information which
# you provide us voluntarily in order to active the App, namely, your [#dt phone
# Number.]
# b.
# The second type of information is individually identifiable
# information ( "Personal Information ").
# This information may identify
# an individual or may be of a private and/or sensitive nature . Personal
# Information may include, without limitation, [#dt User's name], [#dt email address], [#dt date
# of birthday] and certain [#dt personal eating preferences] /
#  We [#a collect] [#dt Non-Personal Information] through your
# use of the Site and/or App . In other words, when you are using the Site
# and/or App we are aware of it and may gather, [#a collect] and record the
# information relating to such usage.
# We also [#a collect]
# [#dt Non-personal Information] which you provide us voluntarily in order to [#p(functionality) active
# the App], namely, your [#dt phone number] . /
#  We [#a collect] [#dt Personal Information]
# which you provide us voluntarily
# when you insert such Personal Information into the
# "Me" segment of the App or when you purchase Beengo Cards using Your
# credit card. We [#a store] the [#dt Personal Information] either independently or through
# the help of our authorized third-party service providers as detailed below./
#  [#dt Non-personal Information] is
# [#a collected] in order to:
# ·
# [#p (analytics) Use it for
# statistical and research purposes] and for [#p customization and improvement of the App
# and/or Site.] /
#  [#p Activate the App]
# [#a using] [#dt User's phone number.] /
#   [#p(marketing) special offers related to the Food
# Establishments] [#p(customization) in accordance with the User's personal eating preferences.]
# ·
# [#p(marketing) Send to the User’s email address gifts], for example on the User’s birthday (for example, free coffee) and/or any promotional emails on behalf of the Food Establishments which we cooperate with.
# ·
# Allow Users to
# [#p(payments:functionality) purchase certain Beengo Cards] (namely, charging cards) through online payment methods
# (namely, ZOOZ).
# ·
# Send to User's
# email address confirmation regarding the purchase of Beengo Cards as well as a
# unique PIN code to be used vis-à-vis the purchased Beengo Cards.
# ·
# Allow Users to
# provide
# [#p feedback with respect to Food Establishments they visit.] /
#  Beengo
# may [#a(share:third party) disclose Personal Information] in the following cases:
# (a) [#p(requirements:legal requirements) to satisfy any applicable law, regulation, legal process, subpoena or
# governmental request;] (b) [#p(requirements) to enforce this Privacy Policy and/or the TOU], including
# investigation of potential violations thereof; (c) to [#p(security) detect, prevent, or otherwise address fraud, security or technical issues;] (d) to [#p(requirements) respond to User's
# support requests]; (e) [#p(requirements:privacy policy compliance) respond to claims that any content available on the Site violates the rights of third-parties]; /
#  may be [#a(share) using third party software and/or App], in order to [#a collect, store] and/or
# [#a process] the information detailed herein. Such software/App include without
#  limitation, Amazon cloud services which privacy policy can be found at:
# http://aws.amazon.com/privacy/
# and PayPal
# website or services (as detailed below).
# 8.
# Payment]
# Beengo accepts payment through certain online
# payment method (namely, ZOOZ) which enables you to [#p send payments] securely
# online using a [#dt credit card] or [#dt bank account]. /
#
#
# Groups for ai.blueplate.app\privacy_policy.txt:
#  Privacy We [#a collect] [#dt(contact data) consumer information], including but not limited to: [#dt Phone Number], [#dt Email], [#dt Spending] and [#dt(app interactions) Site Visit Habits], [#dt Full name], and [#dt address]. By making a purchase and inputting your information,  you agree to us [#a collecting], [#a storing], and [#a using] your data in the following ways. 1: The restaurant may [#p contact you regarding food items or order conditions] for example, to tell you a food item is unavailable, to adjust the fulfillment time, etc. 2: The restaurant and its employees will be able to  see your basic information to make reference to your order or to get in [#p contact with you in case of any changes, or to provide you with order updates.] Employees and owners are not allowed to contact customers for any other purposes than what is within reason to provide order updates. If you suspect abuse, please email support@blueplate.ai immediately. 3: You may be [#p contacted by the Online Ordering Provider (Blueplate) to ask for your feedback regarding the online ordering system] 4: You will be [#p(contact) sent, by our automatic system, an order confirmation email] /
#  Your [#dt email] may be [#a(share) stored by Sendgrid, a Twilio Product], /
#  We may [#a(process:aggregate) use your data in the aggregate] to make [#p(analytics) actionable insights in real time to other restaurants and their employees]./
#  our system may [#a use] your [#dt spending habits] to attempt to [#p(analytics:user habits) predict popular times and rush times], sharing this information with restaurant employees to [#p(analytics:user habits)  prepare appropriately for when they might get busy.] /
#  We may [#a use] [#dt(personal data) data about you] to [#p(customization) link actions across the platform and attribute them to you], for example if you use the same [#dt(spending) card] or the same [#dt email address] on two different platform actions, we’ll [#p(customization) link them to your customer profile] /
#  We may [#a collect] [#dt(app interactions) data about your visit and site habits], such as [#dt(app interactions:clicks) what you click on], how you [#dt(app interactions) interact with the site], [#dt(app interactions:visit timestamps) how long you visit for], and more.
#  We may [#a collect] your [#dt IP address] and other [#dt information regarding your internet connection], mostly for [#p security] purposes /
#  We [#a collect] [#dt cookies],
#  We [#a use] [#dt cookies] exclusively for [#p authentication purposes].]  /
#  we’ll [#a save] your [#dt carts] and abandoned carts so that just in case something happens, you [#p(save state) don’t lose your order progress]. /
#  [#dt Card data] is [#a(share) sent directly to our payment partners], and is never stored on our servers. Saved cards are [#a(share) stored managed by these partners].]  /
#
#
# Groups for ai.halloween.aifilter.art\privacy_policy.txt:
#
#
# Groups for aiart.midjourney.dreamnow\privacy_policy.txt:
#  we [#a collect], [#a use], and protect your [#dt personal information] /
#  We may [#a collect] [#dt personal information] that you provide to us when using the App, such as your [#dt name], [#dt email address], and other contact information. b. Usage Information: We may [#a collect] [#dt(app interactions) information about how you use the App], including your [#dt interactions with the App's features and content]. c. Device Information: We may [#a collect] [#dt information about your device], including its [#dt unique device identifier], [#dt IP address], and [#dt operating system]. /
#  How We [#a Use] Your Information a. Provide and Improve the App:We [#a use] [#dt your information] to [#p provide and improve the App's functionality] and user experience. b. Communication: We may use your contact information to [#p(contact)+(advertisement) communicate with you about updates, promotions, and other relevant information related to the App]./
#
#
# Groups for at.tomtasche.reader.pro\privacy_policy.txt:
#  the [#a collection], [#a use], and [#a disclosure]
# of [#dt Personal Information] if anyone decided to use my Service. /
#  the [#a collection] and [#a use] of information in
# relation to this policy. The [#dt Personal Information] that I [#a collect] is used for [#p(functionality) providing and improving
# the Service]. /
#  Information [#a Collection] and [#a Use]
# For a better experience, while using our Service, I may [#a(collect) require you to provide us] with certain
# [#dt personally identifiable information]. /
#  The app does [#a(share) use third party services that may collect] [#dt(personal data) information used to identify you.] /
#  [#dt Log Data]
# I want to inform you that whenever you use my Service, [#p(security:system security) in a case of
# an error in the app] I [#a collect] data and information (through third party products) on your phone
# called [#dt Log Data]. This [#dt Log Data] may include information such as your device [#dt Internet Protocol (“IP”) address],
# [#dt device name], [#dt operating system version], the configuration of the app when utilizing my Service,
# the [#dt(timestamps) time and date of your use] of the Service, and other statistics. /
#  [#dt Cookies] Cookies are files with a small amount of data that are commonly used as anonymous unique identifiers.
# These are sent to your browser from the websites that you visit and are stored on your device's internal
# memory.
# This Service does not use these “cookies” explicitly.]However, the app may [#a(share) use third party code and
# Libraries use] [#dt “cookies”] to collect information and [#p(functionality) improve their services]. /
#  I may [#a(share) employ third-party companies] and individuals due to the following reasons:
# [#p(functionality) To facilitate our Service];
# [#p(functionality) To provide the Service on our behalf];
# [#p(functionality) To perform Service-related services]; or
# [#p(user habits) To assist us in analyzing how our Service is used].
# I want to inform users of this Service that these third parties have access to
# your [#dt Personal Information]. /
#
#
# Groups for bau.moho.freevpn\privacy_policy.txt:
#  with the [#a collection], [#a use], and disclosure of [#dt Personal
# Information] if anyone decided to use our Service.
# If you choose to use our Service, then you agree to
# the [#a collection] and [#p use] of information in relation to this
# policy. The Personal Information that we collect is
# used for [#p providing and improving the Service]. /
#  we
# may require you to [#a provide us] with certain [#dt personally
# identifiable information]. /
#  The app does use [#a(Transfer: External) third-party services that may collect
# information used to identify you]. /
#  we [#a collect] data and information (through third-party
# products) on your phone called [#dt Log Data]. This Log Data may
# include information such as your device [#dt Internet Protocol
# (“IP”) address], [#dt device name] , [#dt operating system version], /
#  the app may [#a(transfer) use third-party code and libraries] that use
# [#dt “cookies”] to [#p(functionality) collect information and improve their services] /
#
#
# Groups for blizzard.ponderonweather\privacy_policy.txt:
#  Our company [#a collects] the following set of data and information:Personal identification information ( [#dt  name],  [#dt physical address],  [#dt email address],  [#dt phone number]…)  [#dt Images],  [#dt videos] /
#  we [#a collect] data and [#a process] [#dt personal data and information] when: [#p(accounts:functionality) You register online] or [#p(order fulfillment:functionality) place and order for any of our products] /
#   [#a(external: collect) Our company might also receive data] /
#  Our company [#a collects] your data so that we can:[#p Process your order], [#p manage your account] [#p Send you email] /
#  processes your [#dt order] it may [#a(transfer) send your data to credit and banking agencies] to [#p prevent fraudulent purchases] /
#  Our company will [#a(timed:delete) keep your [#dt email] and [#dt first name]  for 90 days] /
#  [#dt Device model (anonymous)] [#dt OS version (anonymous)] [#dt(device information)  Device’s language (anonymous)] [#dt(location) Geolocalisation if provided Country (deducted from geolocalisation) City (deducted from geolocalisation)] /
#   [#dt Personal identification information] ([#dt name], [#dt email address], [#dt phone number…)] Also when you visit our website the following information is automatically received and [#a stored by servers]: [#dt IP address] /
#  to [#p contact you], respond to your message or provide information or services you requested. We [#a use] [#dt(personal data) data you provide] and automatically generated data for [#p statistical analysis to assess what information is of interest to users and system performance]. This allows us to make general improvements to our site. We may also [#a use] [#dt your information] in order to [#p detect, prevent and  respond to security issues] /
#  Our company [#a(transfer) uses a third-party analytics provider] (such as Google Analytics) to [#p analyze data from cookies]. /
#  we may [#a(collect) send cookies or other similar tracking technologies] to your computer or to any other device you use. We [#a use] [#dt cookies] and similar [#dt tracking technologies] to [#p(customization) track user’s preferences and to know how he uses our services]. /
#  we [#a use] your [#dt personal information] and data to provide you with [#p targeted advertisements] or [#p marketing] communications we believe may be of interest to you. For example: We [#a(transfer) use Google Analytics] to help us [#p(analytics:user habits) understand how our customers use the Site]. /
#  The [#p advertisements may be personalized] to reflect your interests. To help determine your interests [#a(transfer) Google and its partners  use cookies]. The cookies are used to [#p(analytics:user habits) track your previous visits to our website and your visits to other websites]. /
#  We can [#a use] different type of [#dt cookie] or [#dt tracking technologies] while you are visiting our website and/or application: Strictly necessary cookies: These types of cookies enable you to access and browse websites and use their features. Without these cookies, services like [#p billing or shopping baskets] cannot work properly. Performance cookies: these cookies collect information and data about how you use our websites and/or application. The data collected can be [#a used] to [#p optimize our websites and/or applications]. These [#dt cookies] are [#a used] to [#p(analytics:user habits) know where our visitors and users are coming from.] These cookies do not collect information that identifies you personally. Functionality cookies: these cookies allow our website or application to remember your choices. They can be [#a used] to [#p memorize] your [#dt localisation], /
#
#
# Groups for bloodpressure.bloodpressureapp.bloodpressuretracker\privacy_policy.txt:
#  we [#a collect] [#dt Cookies] ( Webview browser cookies) - When you visit Forum service, we may send one or more cookies files with small amount of data that is commonly used an anonymous [#dt unique identifier to your mobile device] that uniquely identifies your device
# and allows the application to help you [#p log in faster and enhance your navigation through the Forum]. /
#  Our app may [#a(transfer) use some providers] to [#p show ads]. /
#  We [#a use third party analytics tool, Google Analytics,] to help us [#p(analytics:user habits) measure traffic and usage trends] for the service. Google Analytics [#a collects] information such as [#dt(app interactions)  how often users visit our services,] what [#dt(app interactions) pages they visit] [#dt(timestamps) when they do so], /
#  [#a (consent:external:collect) permit us to import [#dt health data] into the App from third-party services such as Google Fit.] Permitting us to access third party information can help you to [#p(functionality) maximize your App experience], /
#  The PII [#a(collect) we may get from you] in that situation are strictly limited to your [#dt name], [#dt email address], [#dt device information], [#dt location Information] and your survey response only. How we use your information In above situation, we guarantee that your PII will only be used for [#p contacting] you and [#p improving our services]. /
#
#
# Groups for com.adv.flixgo.movies\privacy_policy.txt:
#  MaxPlay Plus Video Player may [#a collect] certain [#dt(personal information) personally identifiable information] from Users in order to [#p(functionality) provide and improve the app's services.] This may include: [#dt Usage Data]: We may collect information on how you use the MaxPlay Plus Video Player app, such as your [#dt(app interactions) interactions with features], [#dt(app interactions) playback history], and preferences. [#dt Device Information]: We may [#a collect] device-specific information, such as the [#dt type of device], [#dt operating system version], and unique [#dt device identifiers]. /
#  MaxPlay Plus Video Player [#a (share) integrates the following third-party services], subject to their respective privacy policies: Google Billing SDK: Used for [#p in-app purchases], billing, and subscription management. Google's privacy policy can be found at:
# https://policies.google.com/privacy Firebase SDK: Used for [#p analytics], crash reporting, and [#p(analytics) performance monitoring]. /
#  We may [#a share] your information with third parties under the following circumstances: With your Consent: We may [#a share] your information with third parties if you give us consent to do so. For [#p(compliance:legal compliance) Legal Reasons]: We may [#a disclose] your information to [#p(compliance:legal compliance) comply with applicable laws, regulations, legal processes, or enforceable governmental requests]. /
#
#
# Groups for com.aisecurity\privacy_policy.txt:
#  Types of Data [#a Collected]
# [#dt Personal Data]
# While using Our Service, We may ask You to provide Us with certain [#dt personally identifiable information] that can be [#a used] to [#p contact] or [#p identify] You. Personally identifiable information may include, but is not limited to:
# [#dt Usage Data]
# [#dt Usage Data]
# [#dt Usage Data] is [#a collected automatically] when using the Service.
# [#dt Usage Data] may include information such as Your Device's [#dt Internet Protocol address] (e.g. [#dt IP address]), [#dt browser type], browser version, the [#dt(app interactions) pages of our Service that You visit], the [#dt(timestamps) time and date of Your visit], the [#dt(timestamps) time spent on those pages], [#dt unique device identifiers] and other [#dt diagnostic data]. /
#  When You access the Service by or through a mobile device, We may [#a collect] certain information automatically, including, but not limited to, the [#dt type of mobile device] You use, Your mobile device [#dt unique ID], the [#dt IP address] of Your mobile device, Your mobile [#dt operating system], the type of mobile Internet browser You use, [#dt unique device identifiers] and other [#dt diagnostic data].
# We may also [#a collect] [#dt(usage data) information that Your browser sends] whenever You visit our Service or when You access the Service by or through a mobile device. /
#  [#a Use] of Your [#dt Personal Data]
# The Company may [#a use] ]#dt Personal Data] for the following purposes:
# [#p(functionality) To provide and maintain our Service] , including to [#p(user habits) monitor the usage of our Service].
# [#p(account management) To manage Your Account]:
# to manage Your registration as a user of the Service. The [#dt Personal Data] You provide can [#p(access) give You access to different functionalities] of the Service that are available to You as a registered user.
# [#p(order fulfillment) For the performance of a contract:]
# the development, compliance and undertaking of the purchase contract for the products, items or services You have purchased or of any other contract with Us through the Service.
# [#p To contact You:] /
#  [#p To contact You] by [#dt email], [#dt telephone] calls, [#dt SMS], /
#  To provide You
# with news, [#p(personalized:advertisement) special offers and general information about other goods, services and events which we offer that are similar to those that you have already purchased or enquired about] unless [#a(revoke:consent) You have opted not to receive such information] /
#  We may [#a use] [#dt Your information] for other purposes, such as [#p data analysis], [#p(user habits) identifying usage trends], [#p(marketing effectiveness)  the effectiveness of our promotional campaigns and to evaluate and improve our Service], /
#  We may [#a share] Your [#dt personal information] in the following situations:
# With Service Providers:
# We may share Your personal information with Service Providers to [#p(user habits) monitor and analyze the use of our Service], to [#p contact You.] /
#  We may [#a share] or transfer Your [#dt personal information] [#p(sale:requirements) in connection with, or during negotiations of, any merger, sale of Company assets, financing, or acquisition /
#  We may [#a share] [#dt Your information] with Our business partners [#p(advertisement) to offer You certain products, services or promotions.] /
#  The Company will [#a retain] Your [#dt Personal Data] only for as long as is necessary for the purposes set out in this Privacy Policy. We will [#a retain] and [#a use] Your [#dt Personal Data] to the extent necessary [#p(legal compliance) to comply with our legal obligations] /
#  The Company will also [#a retain] [#dt Usage Data] for [#p internal analysis] purposes. [#dt Usage Data] is generally retained for a shorter period of time, except when this data is used to strengthen the [#p security] or to improve the [#p functionality] of Our Service, or [#p(legal compliance) We are legally obligated to retain this data for longer time periods./
#  [#a Transfer] of Your [#dt Personal Data]
# Your information, including Personal Data, is [#a processed]  at the Company's operating offices and in any other places where the parties involved in the processing are located. /
#
#
# Groups for Com.app.mmallbooks\privacy_policy.txt:
#  The [#dt Personal Information] that I [#a collect] is used for [#p(functionality) providing and improving the Service]. /
#  I may [#a(collect) require you to provide us with certain personally identifiable information, including but not limited to Pro Learner, [#dt Name] – Mr. Wai Yan. Personal identification numbers: [#dt driver’s license number]- 678904567345. [#dt Contact email] – prolearn77@gmail.com, Contact Address – 289 番地　1 サﾝグローブ　II 401, Uruma-shi, Okinawa, Japan. . The information that I request will be retained on your device and is not collected by me in any way.
# The app does [#a use third-party services] that may collect information used [#p(indentification)  to identify you.] /
#  I [#a collect] data and information (through third-party products) on your phone called [#dt Log Data]. This [#dt Log Data]. may include information such as your [#dt device Internet Protocol (“IP”) address],  the configuration of the app when utilizing my Service, the time a[#dt device name], [#dt operating system version,] and [#dt(app interactions:visit timestamps) date of your use of the Service], and other statistics. /
#  the app may [#a use third-party code] and libraries that use [#dt “cookies”] to [#a collect] information and [#p improve their services.] /
#  I may  [#a(share) employ third-party companies] and individuals due to the following reasons:
# [#p To facilitate our Service;]
# [#p To provide the Service on our behalf;]
# To perform Service-related services; or
# [#p To assist us in analyzing how our Service is used.]
# I want to inform users of this Service that these [#a(share) third parties have access] to their [#dt Personal Information]. /
#
#
# Groups for Com.app.mypersonalweathermanapp\privacy_policy.txt:
#  We may [# a collect] the following information:
# For the [#p(functionality) chat feature to work] properly in your messenger app, we will need to access the [#dt contact list] of app users.
# [#dt name] and [job title]
# contact information including [#dt email address]
# demographic information such as [#dt postcode], /
#  What information do you [#a collect] - This includes both information entered by the user i.e. [#dt profile pic], [#dt phone number], [#dt name], etc or information which is collected automatically i.e. HTTP logs, data usage or anything in the background.
# All user data [#a(collected: stored) uploaded into our system], including users’ [#dt Image information] in the mobile app, is [#a stored] in a personalized and secure location. /
#  We may [#a use] the information to [#p improve our products and services.]
# We may periodically send [#p(advertisement:personalized) promotional emails about new products], special offers or other information which we think you may find interesting using the email address which you have provided.
# From time to time, we may also use your information to [#p(analytics) contact you for market research] purposes. We may [#p contact you] by email, phone, fax or mail. We may use the information to [#p customise the App] according to your interests. /
#  We [#a use] [#dt traffic log cookies] to [#p(analytics:user habits) identify which pages are being used]. /
#  We [#a use] [#dt your data] to [#p provide and improve the Service]. /
#  Types of Data [#a Collected]
# [#dt Personal Data]
# While using our Service, we may ask you to provide us with certain personally identifiable information that can be used to contact or identify you ("Personal Data"). Personally identifiable information may include, but is not limited to:
# [#dt Email address]
# [#dt First name and last name]
# [#dt Phone number]
# [#dt Address, State, Province, ZIP/Postal code, City]
# Cookies and Usage Data
# We may use your Personal Data to [#p(advertisements) contact you with newsletters, marketing or promotional materials] /
#  [#dt Usage Data]
# We may also [#a collect] information how the Service is accessed and used ("Usage Data"). This Usage Data may include information such as your computer's [# dt Internet Protocol address] (e.g. IP address), [#dt browser type], browser version, the [#dt(app interactions) pages of our Service that you visit], the [#dt(app interaction:visit timestamps) time and date of your visit, the time spent on those pages], [#dt unique device identifiers] and other diagnostic data. /
#  [#dt Tracking & Cookies] Data
# We [#a use] [#dt cookies] and similar [#dt tracking technologies] to [#p(analytics) track the activity on our Service] and hold certain information./
#  we [#a use:]
# [#dt Session Cookies]. We [#a use] [#dt Session Cookies] to [#p operate our Service]. /
#  [#dt Preference Cookies]. We [#a use] [#dt Preference Cookies] to [#p(customization:memorization) remember your preferences and various settings.] /
#  [#dt Security Cookies]. We [#a use] [#dt Security Cookies] for [#p security purposes.] /
#  [#dt Advertising Cookies] [#dt Advertising Cookies] are [#a used] to serve you with [#p advertisements that may be relevant to you and your interests.] /
#  My Personal Weatherman [#a uses] the [#dt(personal data) collected data[ for various purposes:
# [#p(functionality) To provide and maintain our Service]
# [#p(contact) To notify you about changes to our Service]
# To allow you to participate in interactive features of our Service when you choose to do so
# To provide customer support
# [#p(analytics) To gather analysis or valuable information so that we can improve our Service]
# [#p(analytics) To monitor the usage of our Service]
# To detect, prevent and address technical issues
# [#p(marketing To provide you with news, special offers and general information about other goods,] /
#  My Personal Weatherman will also [#a retain] [#dt Usage Data] for [#p internal analysis purposes.] [#dt Usage Data] is generally [#a retained] for a shorter period of time, except when this data is used to [#p strengthen the security] or to [#p improve the functionality] of our Service, or we are [#p legally obligated] to retain this data for longer time periods./
#  My Personal Weatherman may [#a disclose] your [#dt Personal Data] in the good faith belief that such action is necessary to:
# [#p(compliance) To comply with a legal obligation]
# [#p(security) To protect and defend the rights or property of My Personal Weatherman]
# [#p(security) To prevent or investigate possible wrongdoing in connection with the Service]
# [#p(security) To protect the personal safety of users of the Service or the public]
# [#p(compliace) To protect against legal liability] /
#  We may [#a(share) use third-party Service Providers] to [#p(analytics) monitor and analyze] the use of our Service.
# Google Analytics
# Google Analytics is a web analytics service offered by Google that tracks and reports [#dt(app interactions) app traffic.] Google uses the data collected to [#p(analytics) track and monitor the use of our Service.] This data is [#a shared with other Google services]. Google may use the collected data to contextualize and [#p personalize the ads] /
#  We may [#a(share) use third-party Service Providers] to [#p show advertisements] to you /
#  Google, as a third party vendor, [#a uses] [#dt cookies] to [#p serve ads] /
#  we [#a use third-party services] for [#p payment processing] (e.g. payment processors).
# We will not store or collect your [#dt payment card details]. /
#
#
# Groups for com.appvision.babygenerator.android\privacy_policy.txt:
#  The app does [#a use third-party services]  that may [#a collect] information used to [#p(identification) identify you]. /
#  We [#a collect] data and information (through third-party products) on your phone called [#dt Log Data]. This [#dt Log Data] may include information such as your device [#dt Internet Protocol (“IP”) address], [#dt device name], [#dt operating system version], the configuration of the app when utilizing my Service, the [#dt(app interactions:visit timestamps) time and date of your use of the Service,] /
#  the app may [#a use third-party] code and libraries that use [#dt “cookies”] to [#a collect] information and [#p(analytics) improve their services]. /
#  these [#a(share) third parties have access] to their [#dt Personal Information.] /
#
#
# Groups for com.banix.drawsketch.ardraw\privacy_policy.txt:
#  which governs our [#a collection] and [#a use] of [#dt your information], which may include [#dt personal data]. As part of our provision of the Service, we may need to [#p(communication) provide you with certain communications], /
#
#
# Groups for com.brandemaker.dailypost\privacy_policy.txt:
#  the [#a collection], [#a use], and [#a disclosure] of [#dt Personal Information] /
#  The [#dt Personal Information]
#  that I [#a collect] is [#a used] for [#p(app functionality) providing and improving the Service]. /
#  Information [#a Collection] and [#a Use] For a [#p(functionality) better experience], while using our Service, I may [#a require you to provide us] with certain [#dt personally identifiable information]. /
#  The app does [#a(share) use third party services that may collect] information used to [#p identify you]. /
#   [#dt Log Data] I want to inform you that whenever you use my Service, [#p(site protection) in a case of an error] in the app I [#a collect] data and information (through third party products) on your phone called [#dt Log Data]. This Log Data may include information such as your device [#dt Internet Protocol (“IP”) address], [#dt device name], [#dt operating system] version, the configuration of the app when utilizing my Service, the [#dt( timestamps) time and date of your use] /
#  the app may [#a use third party] code and libraries that use [#dt “cookies”] to [#p( analytics) collect information] and [#p(functionality) improve their services]. /
#  I may [#a(share) employ third-party] companies and individuals due to the following reasons: [#p(functionality) To facilitate our Service; To provide the Service on our behalf; To perform Service-related services]; or To assist us in [#p(analytics) analyzing how our Service is used]. I want to inform users of this Service that these third parties have access to your [#dt Personal Information]. /
#
#
# Groups for com.charstar.andoid\privacy_policy.txt:
#  We [#a use] Your [#dt Personal data] to [#p(functionality) provide and improve the Service]. By using the Service, You agree to the [#a collection] and [#a use] of information in accordance with this Privacy Policy. /
#  [#a Collecting] and [#a Using] Your [#dt Personal Data]
# Types of Data [#a Collected]
# [#dt Personal Data]
# While using Our Service, We may [#a(collect) ask You to provide Us] with certain [#dt personally identifiable information] that can be used to contact or identify You. Personally identifiable information may include, but is not limited to:
# [#dt Email address]
# [#dt Phone number]
# [#dt Usage Data]
#  Usage Data
#  Usage Data is [#a collected automatically] when using the Service.
# [#dt Usage Data] may include information such as Your Device's [#dt Internet Protocol address] (e.g. {#dt IP address]), [#dt browser type], [#dt browser version], the [#dt(usage data:app interactions) pages of our Service that You visit], the [#dt(usage data: app interactions: visit timestamps) time and date of Your visit], the [#dt(usage data: app interactions: visit timestamps) time spent on those pages], unique [#dt device identifiers] and other [#dt diagnostic data.]
# When You access the Service by or through a mobile device, We may [#a collect] certain information automatically, including, but not limited to, the [#dt type of mobile device] You use, Your mobile device [#dt unique ID], the [#dt IP address] of Your mobile device, Your mobile [#dt operating system], the type of mobile Internet [#dt browser] You use, unique [#dt device identifiers] and other [#dt diagnostic data].
# We may also [#a collect] [#dt(usage data) information that Your browser sends] whenever You visit our Service or when You access the Service by or through a mobile device. /
#  [#dt Tracking Technologies] and [#dt Cookies]
# We [#a use] [#dt Cookies] and similar [#dt tracking technologies] to [#p(analytics:user habits) track the activity on Our Service] and [#a store] certain information. [#dt Tracking technologies] [#a used] are [#dt beacons], [#dt tags], and scripts to [#a collect] and track information and to [#p(analytics) improve and analyze Our Service]. The technologies We use may include:
# [#dt Cookies] or [#dt Browser Cookies.] /
#  We [#a use] both Session and Persistent [#dt Cookies] for the purposes set out below:
# Necessary / Essential Cookies
# Type: [#dt Session Cookies]
# Administered by: Us
# Purpose: These Cookies are essential to [#p(functionality) provide You with services] available through the Website and to [#p(functionality) enable You to use some of its features]. They help to [#p(identify) authenticate users] and [#p(security:user security) prevent fraudulent use of user accounts]. /
#  Type: [#dt Persistent Cookies]
# Administered by: Us
# Purpose: These Cookies allow us to [#p(customization:memorization) remember choices You make when You use the Website], such as remembering your login details or language preference. The purpose of these Cookies is to [#p(customization) provide You with a more personal experience] /
#  [#a Use] of Your [#dt Personal Data]
# The Company may [#a use] [#dt Personal Data] for the following purposes:
# To [#p(functionality) provide and maintain our Service] , including to [#p(analytics:user habits) monitor the usage of our Service.]
# [#p(accounts) To manage Your Account:]
# to manage Your registration as a user of the Service. The Personal Data You provide can give You [#p(functionality:access) access to different functionalities of the Service] /
#  To [#p contact] You:
# To [#p contact] You by [#dt email], [#dt telephone calls], /
#  To provide You
# with news, [#p(advertisement:personalized) special offers and general information about other goods, services and events which we offer that are similar to those that you have already purchased or enquired] about /
#  We may [#a use] [#dt Your information] for other purposes, such as [#p(analytics) data analysis], [#p(analytics: user habits) identifying usage trends], [#p(analytics:marketing effectiveness) determining the effectiveness of our promotional campaigns] and to [#p(analytics:internal analysis) evaluate and improve our Service, products, services, marketing and your experience.] /
#  We may [#a share] Your [#dt personal information] in the following situations:
# With Service Providers:
# We may [#a share] Your [#dt personal information] with Service Providers to [#p(analytics:user habits) monitor and analyze the use of our Service],
# to [#p contact] You.
# [#p(sale) For business transfers:
# We may share or transfer Your personal information in connection with, or during negotiations of, any merger, sale of Company assets], /
#  We may [#a share] [#dt Your information] with Our business partners to [#p(advertisement) offer You certain products, services or promotions.] /
#  [#a Retention] of Your [#dt Personal Data]
# The Company will [#a retain] Your [#dt Personal Data] only for as long as is necessary for the purposes set out in this Privacy Policy. We will [#a retain] and [#a use] Your [#dt Personal Data] to the extent necessary to [#p(requirements:legal compliance) comply with our legal obligations] (for example, if we are required to [#a retain] your data to [#p(requirements:legal compliance) comply with applicable laws]), /
#  The Company will also [#a retain] [#dt Usage Data] for [#p internal analysis] purposes. [#dt Usage Data] is generally [#a retained] for a shorter period of time, except when this data is used to [#p (security) strengthen the security] or to [#p(functionality) improve the functionality of Our Service], or [#p(requirements:legal compliance) We are legally obligated] to [#a retain] this data for longer time periods. /
#  [#a Transfer] of Your [#dt Personal Data]
# Your information, including [#dt Personal Data], is [#a processed] /
#
#
# Groups for com.chula.app\privacy_policy.txt:
#  [#a collection] and [#a use] of your [#dt personal information.] We [#a collect] [#dt personal information] including [#dt name], [#dt physical address], [#dt phone number], [#dt card information], technical data and related information, and your [#dt current location] to [#p(functionality) better your use of the Service with more accuracy.] We [#a collect] this information via direct interactions as you use our website. Chula, LLC does not sell your personal information to the third party but we may use it for [#p(analytics) surveys], [#p(advertisement) contests, promotions] or other programs,manage and execute delivery services, provide customer support and [#p(contact) respond to your inquiries], [#p(security) protect against and prevent fraud, unauthorized transactions, claims and other liabilities]. /
#
#
# Groups for com.cigna.mobile.mycigna\privacy_policy.txt:
#  Information We [#a Collect] [#dt Personal information] is information that identifies you as an individual or relates to an identifiable person. Examples of personal information we may [#a collect] about you through our Services include the following: • Identifiers such as [#dt name], [#dt contact information], [#dt online identifiers], and [#dt government- issued ID] numbers; • Commercial Information related to services we provide such as [#dt medical information], [#dt insurance information], and [#dt financial information]; • Characteristics of Protected Classifications under state or federal law such as age and medical conditions; • Commercial Information such as [#dt(spending) transaction information and purchase history]; • Internet or Network Activity Information such as [#dt browsing history], [#dt(app interactions) interactions with our website], [#dt Internet Protocol (IP) address], [#dt(identifier) Media Access Control (MAC) address]; [#dt operating system] and version; [#dt Internet browser type] and version (for more information, see the Cookies and Similar Technologies section, below); • [#dt Geolocation Data] such as device location; • Audio, Electronic, Visual and Similar Information such as [#dt call] and [#dt video recordings]; /
#  How We [#a Use] [#dt Personal Information] We [#a use] [#dt personal information] received through our Services for various purposes, including the following: • [#p(functionality) Providing our Services to you], including [#p(order fulfillment) completing transactions], processing claims, and providing quotes; • [#p(contact) Providing you with information about our Services], including information about health care, health related services, resources and benefits that will help you manage your health; sending administrative information to you, such as changes to our terms, conditions, and policies; [#p(advertisement) sending marketing information we think may be of interest to you]; and fulfilling any other purpose for which you provide it; • Improving our Services; • Providing and improving customer services, including through email or text communications, or any chat or similar feature available through our services; • Conducting our business, such as [#p data analysis]; audits; developing new products; enhancing, improving or modifying our services; [#p(user habits) identifying usage trends]; determining the effectiveness of our promotional campaigns and operating and expanding our business activities; [#p(personalized:advertisement) tailoring offers and advertisements to you for products or services that you may find helpful on our Services and those on third-party sites]; • Sending you surveys; • [#p(access:functionality) To provide certain functionality], such as allowing you to send messages to a friend through the Services; • [#p(identification) Authenticating or confirming your identity]; • To de-identify it; • Taking any action that we believe to be necessary or appropriate: o to investigate, [#p(security) prevent and detect illegal activities]; o to carry out our obligations and enforce our rights arising from any of our contracts, including for billing and collection; o under applicable laws, including laws outside your country of residence; o to [#p(legal compliance) comply with legal process]; /
#  We may [#a disclose] [#dt personal information] for the following purposes: • [#p(functionality) Operating Services and Sites and Providing Related Support] . To provide and operate our Services, [#p communicate] with you about your use of the Services, provide troubleshooting and technical support, respond to your inquiries, fulfill your orders and requests, and for similar service and support purposes. • [#p(sale:requirements) Business Transfers]. /
#  [#p(legal compliance : requirements) In Response to Legal Process]. We may [#a disclose] your [#dt personal information] [#p(legal compliance : requirements) to comply with the law, a judicial proceeding, court order, or other legal process],/
#  We [#a disclose] your [#dt personal information] when we believe it is appropriate to do so to investigate, prevent, or [#p(legal compliance : requirements) take action regarding illegal activities], suspected fraud, situations involving potential threats to the safety of any person, [#p(policy compliance) violations of our Terms of Use or this Policy,] or as evidence in litigation in which we are involved. /
#  We may [#a disclose] the [#dt personal information] that we collect for the purposes described above with the following parties: • Vendors. We may [#a disclose] [#dt personal information] we collect to our service providers or agents who perform functions on our behalf. These may include, for example,[#p(functionality)  IT service providers], [#p(functionality) help desk], [#p(payments:functionality) payment processors], [#p analytics providers], consultants, auditors, and legal counsel. /
#  Our Affiliates. We may [#a disclose] [#dt personal information] we collect to our affiliates or subsidiaries. • Our Business Customers. Any personal information that we collect and process on behalf of a business client will be disclosed as directed by that business customer. /
#  [#p(advertisement) Third-Party Ad Networks and Providers]. We may [#a disclose] [#dt personal information] to thirdparty ad network providers, sponsors and/or traffic measurement services. These third parties may [#a use] [#dt cookies], JavaScript, [#dt web beacons] (including clear GIFs), and other tracking technologies to measure the effectiveness of their ads and to [#p personalize advertising content to you] /
# ...
# Purposes: ['(functionality) enhance your user experience', '(analytics:user habits) understand the behavior and preferences of our customers', '(advertisements) to serve advertising', '(identification) for authentication purposes', '(requirements:policy requirements) to enforce our Terms of Service', '(functionality) ensure proper functioning of our products and services']
#
# Annotation 9:
# Actions: []
# Data Types: ['non-personal information', 'personal information', 'email address']
# Purposes: ['(contact) providing excellent customer service', '(accounts) administering loyalty programs', '(communication) tailoring our communications, offerings, web pages or game play']
#
# Annotation 10:
# Actions: ['transferred']
# Data Types: ['(personal data) customer information']
# Purposes: ['(sale) event of a merger, acquisition, or the unlikely event of bankruptcy']
#
# Annotation 11:
# Actions: ['(share) employs third party contractors to collect']
# Data Types: ['personal information', 'name', 'mailing address', 'telephone number', 'email address']
# Purposes: ['(contact) email delivery, product, prize or promotional fulfillment', '(access) contest administration', '(functionality:payments) credit card processing, shipping or other services on our sites']
#
# Annotation 12:
# Actions: ['(external:collect) ask some third party contractors, such as credit agencies, data analytics or market research firms, to supplement']
# Data Types: ['personal information']
# Purposes: ['(analytics) marketing and demographic studies', '(internal analysis) improve our sites and related advertising to better meet our visitors’ needs and preferences']
#
# Annotation 13:
# Actions: ['(collect:external) tie this information', '(collect) you provide to us']
# Data Types: ['personal information']
# Purposes: ['(user habits) To enrich our understanding of individual customers']
#
# Annotation 14:
# Actions: ['disclose', 'disclosure']
# Data Types: ['personal information', '(messages) personal communications']
# Purposes: ['(policy requirements) report abuse functions in our products and services', '(requirements: legal compliance) enforce legal rights and comply with the law, or to comply with an order from a government entity or other competent authority', '(system security) to address potential or actual injury or interference with our rights, property, operations']
#
#
# File: com.space.saver.new.photo\privacy_policy.txt
#
# Annotation 1:
# Actions: ['Collect', 'collect']
# Data Types: ['Device information', 'network connection information']
# Purposes: ['(functionality) provide you better experience']
#
# Annotation 2:
# Actions: ['store', 'retain']
# Data Types: ['(OS version) SDK/API/JS code version', 'IP address', 'timestamp', 'device identifier', 'operating system version', 'location', '(location) time zone and the network state (Wi-Fi and so on), the CPU, and the battery use, Screen resolution, Memory usage, Storage usage, sim operator, sim card country, Application release status in google play, Ad loading strategy, Ad platform and advertising placement id. Phone height and width,sim operator name,[#dt os version', 'personal information', 'landing pages', '(user habits) pages viewed and order of those pages', '(timestamps) time spent on particular pages', '(timestamps) date and time of your request']
# Purposes: []
#
# Annotation 3:
# Actions: ['(share) Advertisers may store']
# Data Types: ['cookies']
# Purposes: ['(functionality) improve the product experience']
#
# Annotation 4:
# Actions: ['(share) Third-party SDKs integrated in our app may access', '(share) Advertisers may store', '(share) collected by third-party SDKs']
# Data Types: ['IP address', '(device information) Data associated with your device', 'device type', 'technological information', 'cookies']
# Purposes: []
#
# Annotation 5:
# Actions: ['use', 'used']
# Data Types: ['Android Advertising ID', 'Android advertising identifier']
# Purposes: ['(advertisements personalized) customized advertisement experience', 'advertising', 'analytics']
#
# Annotation 6:
# Actions: ['collect information']
# Data Types: []
# Purposes: []
#
# Annotation 7:
# Actions: ['Use', 'collect', 'process', 'process']
# Data Types: []
# Purposes: ['(functionality) improve and optimize the Services', '(functionality) provide better Services', '(functionality) Update and develop the Services Develop and improve your experience', '(communications) Respond to your comments and questions', '(advertisement) Provide offers', '(communication) Send related information (e.g. updates, security alerts, support messages)', '(functionality) To provider the Services']
#
# Annotation 8:
# Actions: ['use']
# Data Types: ['ad identifiers', 'age', '(location) country, region', '(device information: app information) games played by you', '(usage data:app interactions) interaction of you with the Services and with other users']
# Purposes: ['advertisements and marketing', '(personalized:advertisement) send you personalized advertising and marketing']
#
# Annotation 9:
# Actions: ['(share) use various third party', 'share', 'process', '(share) Pass the information collected from you to third party']
# Data Types: []
# Purposes: ['advertising and marketing', '(personalized:advertisement) target and improve our advertising and marketing materials', 'advertising and marketing']
#
# Annotation 10:
# Actions: ['collecting', 'using']
# Data Types: ['(personal data) information about you']
# Purposes: ['(advertisements:personalized) personalize advertising and marketing materials', '(functionality) improve your experience']
#
# Annotation 11:
# Actions: ['Share', 'personal information', 'shared with our third-party partners', 'disclose', 'use']
# Data Types: ['personal information', 'personal information']
# Purposes: ['show you advertisements', '(user habits:analytics) measure your ad/site interaction', '(user habits:analytics) understand the site and app traffic usage or user behavior']
#
# Annotation 12:
# Actions: ['process', 'process']
# Data Types: ['Personal Data', 'personal data']
# Purposes: ['(functionality) provide you with the services', '(identification) identify and authenticate you', '(requirements:business requirements) applicable accounting rules', '(requirements: legal compliance) mandatory disclosures to law enforcement']
#
# Annotation 13:
# Actions: ['share']
# Data Types: ['cookies']
# Purposes: ['advertising purposes']
#
# Annotation 14:
# Actions: ['required to provide us', 'processing']
# Data Types: ['Personal Data']
# Purposes: ['(functionality) provide you all of our services']
#
#
# File: com.virus.remover\privacy_policy.txt
#
# Annotation 1:
# Actions: ['collect']
# Data Types: ['Personal Information']
# Purposes: ['(functionality) providing and improving the Service']
#
# Annotation 2:
# Actions: ['use third party']
# Data Types: []
# Purposes: ['(identification) used to identify you.']
#
# Annotation 3:
# Actions: ['collect']
# Data Types: ['Log Data', 'Log Data', 'Internet Protocol (“IP”)', 'operating system version', '(timestamps) time and date of your use of the Service']
# Purposes: ['(site security) in a case of an error in the app']
#
# Annotation 4:
# Actions: ['(share) the app may use third party']
# Data Types: ['“cookies”']
# Purposes: ['(analytics) to collect information and improve their services.']
#
# Annotation 5:
# Actions: ['(share) We may employ third-party companies']
# Data Types: []
# Purposes: ['(functionality) To facilitate our Service; To provide the Service on our behalf; To perform Service-related services', '(analytics:user habits) To assist us in analyzing how our Service is used', '(user habits) To analyze data about users interaction with our Application', '(site security) To find and fix bugs and crashes', '(support) To provide customer support']
#
# Annotation 6:
# Actions: ['(share) collect and transfer to UserX']
# Data Types: ['( anonymized:app interactions) anonymized data about users’ actions in the app', '(app interactions) data about features that users use in the app', '(clicks) data about users taps and swipes in the app', 'virtual device identifier']
# Purposes: []
#
#
# File: de.twokit.video.tv.cast.browser.lg.pro\privacy_policy.txt
#
# Annotation 1:
# Actions: []
# Data Types: []
# Purposes: ['(contact:support) Customer Support', 'Security, Safety, and Dispute Resolution', '(analytics) Product Performance Analysis', 'Communications and Product Announcements']
#
# Annotation 2:
# Actions: ['collect', 'collect']
# Data Types: ['Personal information', 'Name', 'Email address', 'Location data', 'IP address', '(social media accounts details) Social identifiers (e.g. Twitter or Facebook user IDs)', 'Mobile device model', 'operating systems', 'Payment information', 'App Activity', '(app interactions) app usage indicators', '(app interactions) usage events in the app', '(app interactions) usage statistic data']
# Purposes: ['improve the Website', '(analytics) business analytics purposes.']
#
# Annotation 3:
# Actions: ['Automatic data collection', '(share) use industry standard Google Analytics tracking', '(request:consent) you will be prompted to give your consent to this privacy policy', '(revoke:consent) you can opt-out of collecting non-personally-identifying analytics data at any time in the App Settings -> Diagnostics & Usage']
# Data Types: []
# Purposes: ['(user habits) Usage Tracking']
#
# Annotation 4:
# Actions: ['use', 'share']
# Data Types: ['cookies', '(anonymized:user habits)  anonymized information about your use of our websites']
# Purposes: ['personalize content', '(user habits) analyse access to our websites']
#
# Annotation 5:
# Actions: ['(share) use third-party providers']
# Data Types: ['Personal information', 'email address']
# Purposes: ['(functionality) services like website and email hosting']
#
# Annotation 6:
# Actions: ['share']
# Data Types: ['personal information', 'IP address']
# Purposes: []
#
#
# File: ee.mtakso.client\privacy_policy.txt
#
# Annotation 1:
# Actions: ['process', 'process']
# Data Types: ['Personal data', 'Contact details', 'name', 'phone number', 'e-mail address', 'home address', 'profile picture', 'driver license details', 'Geolocation', 'Payment information', '(spending info) amount charged', 'payment card', '(account information: messages) Communication and correspondence records', 'IP address', '(transportation data) data about journey status', '(transportation data) vehicle speed, engine power, driving style information']
# Purposes: []
#
# Annotation 2:
# Actions: ['collect', 'process']
# Data Types: ['personal data', 'geolocation']
# Purposes: ['(functionality:access) direct a driver to your location for pick-up, nor can we show you one of our own vehicles close to you for hire']
#
# Annotation 3:
# Actions: ['process', 'collect', 'process', 'processed']
# Data Types: ['personal data', 'personal data', '(account info:messages) Instant messages directly in the Bolt app']
# Purposes: ['(functionality:access) provide you with one or more of our transportation services', '(functionality:order fulfillment:localization) connecting passengers with drivers so you can be picked up and dropped off', '(functionality:localization) show you where our nearest available hire-vehicles are located', '(contact:support) provide service and customer support', 'security purposes', 'analysis']
#
# Annotation 4:
# Actions: ['collection', '(collect:stop) stops after closing the Bolt app', 'use']
# Data Types: ['geolocation data', 'geolocation']
# Purposes: ['(functionality:order fulfillment:localization) make sure you get to your destination']
#
# Annotation 5:
# Actions: ['use']
# Data Types: ['contact details']
# Purposes: ['(contact) notify passengers and riders of updates to the Bolt app']
#
# Annotation 6:
# Actions: ['(collect) gather']
# Data Types: ['(usage data)  data from the device']
# Purposes: ['(identification) authentication and verification checks.']
#
# Annotation 7:
# Actions: ['collect']
# Data Types: ['(localization) data on the routes taken by our passengers and riders']
# Purposes: ['(analytics:system analysis) analyse geographic coverage.']
#
# Annotation 8:
# Actions: ['collect', 'process']
# Data Types: ['payment details']
# Purposes: ['(functionality: order fulfillment) on behalf of drivers for ride-hailing']
#
# Annotation 9:
# Actions: ['collect']
# Data Types: ['(location) data about journey statuses']
# Purposes: ['(requirements:policy compliance) promote compliance with our terms and conditions']
#
# Annotation 10:
# Actions: []
# Data Types: ['name', 'phone number', 'email address', 'used']
# Purposes: ['communicate']
#
# Annotation 11:
# Actions: ['process']
# Data Types: ['(sensor data) data collected through the sensors']
# Purposes: ['security purposes']
#
# Annotation 12:
# Actions: ['process']
# Data Types: ['personal data']
# Purposes: ['(security:site security) exercise or defence of legal claims in case we need to defend against or give proof of claims for damages, or other claims submitted to us for investigation.']
#
# Annotation 13:
# Actions: ['deleted']
# Data Types: ['personal data']
# Purposes: ['(account closed) account is closed']
#
# Annotation 14:
# Actions: ['(delete:timed) stored for three years after the last journey']
# Data Types: ['Financial data']
# Purposes: []
#
# Annotation 15:
# Actions: ['(delete:timed) is stored 6 months.']
# Data Types: ['(sensore data) Data on sensors']
# Purposes: []
#
# Annotation 16:
# Actions: ['retention', '(delete:timed)  recordings are automatically deleted after 24 hours']
# Data Types: ['(device info: audio) audio recording data']
# Purposes: []
#
# Annotation 17:
# Actions: ['(consent:request) given us permission to do so']
# Data Types: ['e-mail address', 'phone number', '(app interactions) information on how you use Bolt’s services']
# Purposes: ['(advertisement) direct marketing messages', '(advertisement:personalized) personalise direct marketing messages']
#
#
# File: psplay.grill.com\privacy_policy.txt
#
# Annotation 1:
# Actions: ['collect']
# Data Types: ['Personal Information', 'log files']
# Purposes: ['finding errors']
#
# Annotation 2:
# Actions: ['(collect) require you to provide us', '(share) use third party services']
# Data Types: ['personally identifiable information']
# Purposes: []
#
# Annotation 3:
# Actions: ['collect']
# Data Types: ['Log Data', 'Log Data', 'Internet Protocol (“IP”) address', 'operating system version', '(timestamps) time and date of your use of the Service', 'Log Data']
# Purposes: []
#
# Annotation 4:
# Actions: ['(share) employ third-party companies']
# Data Types: []
# Purposes: ['(analytics) To assist us in analyzing how our Service is used.']
#
#
# File: stepcounter.pedometer.stepstracker\privacy_policy.txt
#
# Annotation 1:
# Actions: ['use']
# Data Types: ['Personal data']
# Purposes: ['provide']
#
# Annotation 2:
# Actions: ['Collect', 'Use']
# Data Types: ['Personal Data', 'Personal Data', 'personally identifiable information', 'Email address', 'First name', 'last name', 'Usage Data', 'Age', 'Gender', 'Weight', 'Height']
# Purposes: ['contact', 'identify You']
#
# Annotation 3:
# Actions: ['collect']
# Data Types: ['Log Data', 'Log Data', 'Internet Protocol (“IP”) address', 'device name', 'operating system', '(timestamps) time and date of your use of the Service']
# Purposes: ['error']
#
# Annotation 4:
# Actions: []
# Data Types: ['health data', 'Physical Activity', 'Location']
# Purposes: ['(functionality) permission to count your steps.']
#
# Annotation 5:
# Actions: ['collect']
# Data Types: ['Personal data', "Social Media Service's account", 'Your name', 'email address', 'contact list']
# Purposes: ['(accounts) create an account']
#
# Annotation 6:
# Actions: ['retain']
# Data Types: ['Usage Data']
# Purposes: ['internal analysis', 'security', 'functionality', '(legal compliance) legally obligated']
#
# Annotation 7:
# Actions: ['disclose', 'disclose']
# Data Types: ['Personal Data', 'Personal Data']
# Purposes: ['(legal compliance) required to do so by law', '(legal compliance) Comply with a legal obligation']
#
# Annotation 8:
# Actions: ['(share) Google, as a third party vendor']
# Data Types: ['cookies']
# Purposes: ['(advertisement) to serve ads on our Service']
#
# Annotation 9:
# Actions: ['(revoke:consent) withdraw Your consent', 'using']
# Data Types: ['Personal Data']
# Purposes: []
#
# Annotation 10:
# Actions: ['deletion']
# Data Types: ['Personal Data']
# Purposes: []

# %%
# Functions to match similar data types and actions according to their appearance in the ontology 
import json
import nltk
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('wordnet')

def load_ontology(file_path):
    try:
        with open(file_path, 'r') as file:
            ontology_data = json.load(file)
        return ontology_data
    except FileNotFoundError:
        print(f"Error: The ontology file '{file_path}' was not found.")
        return None
    except Exception as e:
        print(f"Error: An error occurred while loading the ontology file. {str(e)}")
        return None

#TODO Get working for multiple words 
def find_category_level_in_sentence(sentence, ontology):
    lemmatizer = WordNetLemmatizer()
    stemmer = PorterStemmer()
    words = sentence.split()
    wordsList = []
    for word in words:
        cleaned_word = word.strip("()")
        lemmatized_word = lemmatizer.lemmatize(cleaned_word)
        stemmed_word = stemmer.stem(lemmatized_word)
        wordsList.append(word)
        if len(wordsList) > 1:
            # First try to find the original word from the ontology
            level = find_category_level(' '.join(wordsList), ontology)  # Join multiple words into a single string
            if level is not None:
                return ' '.join(wordsList), level

        # Try to find the original word from the ontology for lemmatized and stemmed versions
        level = find_category_level(lemmatized_word, ontology)
        if level is not None:
            return cleaned_word, level

        level = find_category_level(stemmed_word, ontology)
        if level is not None:
            return cleaned_word, level

    return None, None

#Update to search for word in any form being within certain layer if is action , data type or purpose 
def find_category_level(word, category=None, level=0):
    if category is None:
        category = ontology
    if isinstance(category, dict):
        for key, value in category.items():
            if word.lower() in key.lower():
                return level
            elif isinstance(value, dict):
                result = find_category_level(word, value, level=level + 1)
                if result is not None:
                    return result
            elif isinstance(value, list):
                for item in value:
                    if isinstance(item, dict):
                        result = find_category_level(word, item, level=level + 1)
                        if result is not None:
                            return result
                    elif isinstance(item, str) and word.lower() in [syn.lower() for syn in value]:
                        return level
    return None

# Load the ontology data from a local JSON file
ontology = load_ontology('../privacy_ontology.json')

if ontology is not None:
    # Example usage:
    for file in os.listdir('../policies_annotated/policies_annotated_text/'):
        sentence = "app interactions"
        word_to_find, level = find_category_level_in_sentence(sentence, ontology)
        if word_to_find is not None:
            print(f"The word '{word_to_find}' is found at level {level} in the ontology.")
        else:
            print(f"No word found in the sentence that is in the ontology.")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Baldw\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Baldw\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Now for processing the data safety section, we can automatically annotate all of the items as they would appear in the ontology and load these into annotated texts which can be processed into a graph.

# %%
# Functions to attribute the words within data safety to the privacy ontology 

def find_in_ontology(input_string, ontology):
    """
    Load a JSON file and find the level and path for a multi-word input, using real stemming.
    It prioritizes multi-word matches before checking individual words.

    :param input_string: The string to search for in the JSON data.
    :param ontology: Path to the JSON file.
    :return: A tuple with the level and path at which the string is found, or None if not found.
    """
    stemmer = PorterStemmer()
    words = input_string.split()

    def stem_words(word_list):
        return ' '.join([stemmer.stem(word.lower()) for word in word_list])

    def search_nested(data, level, path, search_term):
        if isinstance(data, dict):
            for key, value in data.items():
                key_stem = stemmer.stem(key.lower())
                if search_term == key_stem:
                    return level, path + [key]
                found_level, found_path = search_nested(value, level + 1, path + [key], search_term)
                if found_level:
                    return found_level, found_path
        elif isinstance(data, list):
            for item in data:
                item_stem = stemmer.stem(item.lower())
                if search_term == item_stem:
                    return level, path
        return None, []

    with open(ontology, 'r') as file:
        json_data = json.load(file)

    # Search for the whole phrase first
    stemmed_phrase = stem_words(words)
    level, path = search_nested(json_data, 1, [], stemmed_phrase)
    if level:
        return level, path

    # If not found, search for smaller groups of words, then individual words
    for i in range(len(words), 0, -1):
        for j in range(len(words) - i + 1):
            stemmed_group = stem_words(words[j:j+i])
            level, path = search_nested(json_data, 1, [], stemmed_group)
            if level:
                return level, path

    return None, []

# File path to the JSON file
ontology = '../privacy_ontology.json'

# Testing the function with "use third party" and "app interactions"
input_strings = ['cart']
for input_string in input_strings:
    level, path = find_in_ontology(input_string, ontology)
    print(f"Input: '{input_string}' found at level {level}, path: {path}")

def annotate_text_with_ontology_tags(text, ontology):
    """
    Annotates a given text with tags based on whether words or phrases match entries in the ontology.
    Tags are [#a] for actions, [#dt] for data types, and [#p] for purposes.
    Only stems words for matching actions and data types, not purposes.

    :param text: The text to annotate.
    :param ontology: Path to the ontology JSON file.
    :return: The annotated text.
    """
    stemmer = PorterStemmer()

    def stem_word(word):
        return stemmer.stem(word.lower())

    with open(ontology, 'r') as file:
        ontology = json.load(file)

    # Flatten the ontology for easier searching
    flattened_ontology = {}
    def flatten_ontology(data, category, path=[]):
        if isinstance(data, dict):
            for key, value in data.items():
                if category in ["Actions", "Data Types"]:
                    key_stem = stem_word(key)
                else:
                    key_stem = key.lower()  # Do not stem for "Purpose"
                flattened_ontology[key_stem] = (category, path + [key])
                flatten_ontology(value, category, path + [key])
        elif isinstance(data, list):
            for item in data:
                if category in ["Actions", "Data Types"]:
                    item_stem = stem_word(item)
                else:
                    item_stem = item.lower()  # Do not stem for "Purpose"
                flattened_ontology[item_stem] = (category, path)

    for category, data in ontology.items():
        flatten_ontology(data, category)

    # Split the text into words
    words = text.split()

    # Function to get category tag
    def get_tag(category):
        if category == "Actions":
            return "[#a]"
        elif category == "Data Types":
            return "[#dt]"
        elif category == "Purpose":
            return "[#p]"
        return ""

    # Annotate the text
    annotated_words = []
    skip_next = False
    for i in range(len(words)):
        if skip_next:
            skip_next = False
            continue

        # Check for two-word matches
        if i < len(words) - 1:
            two_word_action_data = stem_word(words[i] + ' ' + words[i + 1])
            two_word_purpose = (words[i] + ' ' + words[i + 1]).lower()
            if two_word_action_data in flattened_ontology or two_word_purpose in flattened_ontology:
                key = two_word_action_data if two_word_action_data in flattened_ontology else two_word_purpose
                category, _ = flattened_ontology[key]
                annotated_words.append(get_tag(category) + words[i] + ' ' + words[i + 1] + get_tag(category))
                skip_next = True
                continue

        # Check for one-word matches
        one_word_action_data = stem_word(words[i])
        one_word_purpose = words[i].lower()
        if one_word_action_data in flattened_ontology or one_word_purpose in flattened_ontology:
            key = one_word_action_data if one_word_action_data in flattened_ontology else one_word_purpose
            category, _ = flattened_ontology[key]
            annotated_words.append(get_tag(category) + words[i] + get_tag(category))
        else:
            annotated_words.append(words[i])

    return ' '.join(annotated_words)


#(The output of running data_safety_scraper for ai.blueplate.app)
text = ("Data shared Data that may be shared with other companies or organizations Financial info User payment info and Purchase history Data shared and for what purpose info User payment info App functionality Purchase history App functionality Analytics Developer communications Advertising or marketing Personalization Account management Personal info Name Email address and Phone number Data shared and for what purpose info Name App functionality Email address App functionality Analytics Advertising or marketing Phone number App functionality App activity App interactions Data shared and for what purpose info App interactions App functionality Analytics Personalization Account management Data collected Data this app may collect Personal info Name User IDs and Address Data collected and for what purpose info Name App functionality Analytics Developer communications Advertising or marketing Personalization Account management User IDs App functionality Analytics Account management Address Optional App functionality Advertising or marketing App activity App interactions Data collected and for what purpose info App interactions App functionality Analytics Fraud prevention security and compliance Personalization Security practices Data is encrypted in transit Your data is transferred over a secure connection You can request that data be deleted The developer provides a way for you to request that your data be deleted info For more information about collected and shared data see the developer's privacy policy")
# Annotating the text
annotated_text = annotate_text_with_ontology_tags(text, ontology)
annotated_text = annotated_text.lower()
print(annotated_text)
# Out:
# Input: 'cart' found at level 4, path: ['Data Types', 'Personal Data', 'Financial', 'Carts']
# data [#a]shared[#a] data that may be [#a]shared[#a] with other companies or organizations [#dt]financial[#dt] info user payment info and [#dt]purchase history[#dt] data [#a]shared[#a] and for what purpose info user payment info app [#p]functionality[#p] [#dt]purchase history[#dt] app [#p]functionality[#p] [#p]analytics[#p] developer communications [#p]advertising[#p] or [#p]marketing[#p] [#p]personalization[#p] [#p]account management[#p] personal info [#dt]name[#dt] [#dt]email address[#dt] and [#dt]phone number[#dt] data [#a]shared[#a] and for what purpose info [#dt]name[#dt] app [#p]functionality[#p] [#dt]email address[#dt] app [#p]functionality[#p] [#p]analytics[#p] [#p]advertising[#p] or [#p]marketing[#p] [#dt]phone number[#dt] app [#p]functionality[#p] [#dt]app activity[#dt] [#dt]app interactions[#dt] data [#a]shared[#a] and for what purpose info [#dt]app interactions[#dt] app [#p]functionality[#p] [#p]analytics[#p] [#p]personalization[#p] [#p]account management[#p] data [#a]collected[#a] data this app may [#a]collect[#a] personal info [#dt]name[#dt] [#dt]user ids[#dt] and [#dt]address[#dt] data [#a]collected[#a] and for what purpose info [#dt]name[#dt] app [#p]functionality[#p] [#p]analytics[#p] developer communications [#p]advertising[#p] or [#p]marketing[#p] [#p]personalization[#p] [#p]account management[#p] [#dt]user ids[#dt] app [#p]functionality[#p] [#p]analytics[#p] [#p]account management[#p] [#dt]address[#dt] optional app [#p]functionality[#p] [#p]advertising[#p] or [#p]marketing[#p] [#dt]app activity[#dt] [#dt]app interactions[#dt] data [#a]collected[#a] and for what purpose info [#dt]app interactions[#dt] app [#p]functionality[#p] [#p]analytics[#p] [#p]fraud prevention[#p] [#p]security[#p] and [#p]compliance[#p] [#p]personalization[#p] [#p]security[#p] practices data is encrypted in transit [#dt]your data[#dt] is [#a]transferred[#a] over a secure connection you can request that data be [#a]deleted[#a] the developer provides a way for you to request that [#dt]your data[#dt] be [#a]deleted[#a] info for more information about [#a]collected[#a] and [#a]shared[#a] data see the developer's privacy policy

# %%
#Annotate all of the data safety files created in processing docx file 
import os
import json
from nltk.stem import PorterStemmer
def process_data_safety_files(base_directory, ontology_path):

    # Iterate through subdirectories and process each data safety file
    for subdir in os.listdir(base_directory):
        subdir_path = os.path.join(base_directory, subdir)
        if os.path.isdir(subdir_path):
            data_safety_file = os.path.join(subdir_path, 'data_safety.txt')
            annotated_file = os.path.join(subdir_path, 'data_safety_annotated.txt')

            if os.path.exists(data_safety_file):
                # Read the data safety text
                with open(data_safety_file, 'r', encoding='utf-8') as file:
                    data_safety_text = file.read()

                # Annotate the text
                annotated_text = annotate_text_with_ontology_tags(data_safety_text, ontology)

                # Save the annotated text
                with open(annotated_file, 'w', encoding='utf-8') as file:
                    file.write(annotated_text)
                # print(f"Annotated file saved in {annotated_file}")

# File path to the JSON ontology file
ontology = '../privacy_ontology.json'

# Process all data safety files
process_data_safety_files(annotation_dir, ontology)
