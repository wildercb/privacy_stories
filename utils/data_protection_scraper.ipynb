# %%
import requests
from bs4 import BeautifulSoup
import os
import regex as re
import wordninja

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}


def process_app_page(app_id, directory_path):
    failed_apps = []  # List to store app ids/names for which scraping failed

    # Check if data_protection.txt already exists in the directory
    if os.path.exists(os.path.join(directory_path, 'data_protection.txt')):
        print(f"Skipping {app_id} - data_protection.txt already exists.")
        return

    # The URL of the Google Play Store page
    url = f'https://play.google.com/store/apps/datasafety?id={app_id}&hl=en_US&gl=US'

    try:
        # Send a GET request to the URL with headers and a timeout
        response = requests.get(url, headers=headers, timeout=10)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the page
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find the div with the class 'i1GNIe'
            main_div = soup.find(class_='i1GNIe')

            if main_div:
                # Extract and split the text content within the div by newlines
                div_text = main_div.get_text().strip()

                # Remove the initial part of the text
                start_index = div_text.lower().find("data shared")
                if start_index != -1:
                    div_text = div_text[start_index:]

                # Use regular expression to replace 'expand_more' with an empty string
                formatted_text = re.sub(r'expand_more', '', div_text, flags=re.IGNORECASE)

                # Split words using wordninja
                split_words = wordninja.split(formatted_text)

                # Join the split words with spaces
                formatted_text = ' '.join(split_words)

                # Create the directory if it doesn't exist
                os.makedirs(directory_path, exist_ok=True)

                # Define the file path
                file_path = os.path.join(directory_path, 'data_protection.txt')

                # Write the formatted text to the file
                with open(file_path, 'w', encoding='utf-8') as file:
                    file.write(formatted_text)

                print(f"Output written to {file_path}")
            else:
                print(f"Failed to retrieve the page. Unable to find the div with class 'i1GNIe' for {app_id}")
                failed_apps.append(app_id)
        else:
            print(f"Failed to retrieve the page. Status code: {response.status_code} for {app_id}")
            failed_apps.append(app_id)
    except requests.exceptions.Timeout:
        print(f"Timeout error: The request timed out for {app_id}")
        failed_apps.append(app_id)
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e} for {app_id}")
        failed_apps.append(app_id)
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        failed_apps.append(app_id)
    # Write the failed app ids/names to a text file
    with open('failed_apps.txt', 'w') as failed_apps_file:
        for app_id in failed_apps:
            failed_apps_file.write(app_id + '\n')

'''# Loop through app directories
for app_id in os.listdir('policies_descriptions'):
    # Define the directory structure
    directory_path = os.path.join('policies_descriptions', app_id)

    
    # Process the app page
    process_app_page(app_id, directory_path)'''

app_id = 'ai.blueplate.app'
directory_path = '.'
process_app_page(app_id, directory_path)
# Out:
# Output written to .\data_protection.txt

# %%
# Loop through app directories
for country in os.listdir('eu_top_100/output'):
    for app in os.listdir(f'eu_top_100/output/{country}/free'):
            
        # Define the directory structure
        directory_path = os.path.join(f'eu_top_100/output/{country}/free', app)

        # Process the app page
        process_app_page(app, directory_path)
    for app in os.listdir(f'eu_top_100/output/{country}/paid'):
            
        # Define the directory structure
        directory_path = os.path.join(f'eu_top_100/output/{country}/paid', app)

        # Process the app page
        process_app_page(app, directory_path)
# Out:
# Output written to eu_top_100/output/Austria/free\ai.chat.gpt.bot\data_protection.txt
# Output written to eu_top_100/output/Austria/free\aplicacion.tiempo\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.apptec.europlasma\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.atrust.tanapp\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.austrosoft.t4me.MB_Wien40100\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.bipa.bipaapp2\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.bluesource.mobilepocket\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.drei.up3\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.erstebank.george\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.erstebank.securityapp\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.gv.oe.app\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.gv.oe.awp.eausweise\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.helloagain.muellerde\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.joeclub.app.joecard\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.lieferservice.android\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.mjam\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.oeamtc.android\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.oebb.ts\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.post.app\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.raiffeisen.mobilepay\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.rsg.pfp\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.spar.app\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.tmobile.android.myt\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.uniqa.myuniqa.ionic\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.wienerlinien.wienmobillab\data_protection.txt
# Output written to eu_top_100/output/Austria/free\at.willhaben\data_protection.txt
# Failed to retrieve the page. Unable to find the div with class 'i1GNIe' for at.win2day.games
# Output written to eu_top_100/output/Austria/free\at.zappn\data_protection.txt
# Output written to eu_top_100/output/Austria/free\bloodpressure.bloodpressureapp.bloodpressuretracker\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.adobe.reader\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.amazon.avod.thirdpartyclient\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.amazon.dee.app\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.amazon.mp3\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.amazon.mShop.android.shopping\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.app.tgtg\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.apple.movetoios\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.appsky.android.bloodpressure\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.appswing.qr.barcodescanner.barcodereader\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.autoscout24\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.azure.authenticator\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.bestsecret.main\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.bigwinepot.nwdn.international\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.blizzard.messenger\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.bloodpressuretracker.bloodbressure.bloodpressurelog\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.booking\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.bpfit.bloodpressure.health\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.canda.mobileapp\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.cbs.ca\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.discord\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.disney.disneyplus\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.duolingo\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.einnovation.temu\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.ezt.pdfreader.pdfviewer\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.facebook.katana\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.facebook.orca\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.ford.fordpass\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.fressnapf.mobileapp\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.gamma.scan\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.google.android.apps.authenticator2\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.google.android.apps.chromecast.app\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.google.android.apps.translate\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.google.android.apps.walletnfcrel\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.google.android.apps.youtube.kids\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.hp.printercontrol\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.ingka.ikea.app\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.instagram.android\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.lemon.lvoverseas\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.lidl.eci.lidlplus\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.lovebirthday.heartstikers.emojigif.whatsapp\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.mcdonalds.mobileapp\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.microsoft.bing\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.microsoft.teams\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.myklarnamobile\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.netflix.mediaclient\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.openai.chatgpt\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.paypal.android.p2pmobile\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.photoaid.photo.id\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.pinterest\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.point4more.ios.tak.user.prod\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.pragonauts.notino\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.sec.android.easyMover\data_protection.txt
# Failed to retrieve the page. Unable to find the div with class 'i1GNIe' for com.sezaakapp
# Output written to eu_top_100/output/Austria/free\com.snapchat.android\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.solocode.anton\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.spotify.music\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.teacapps.barcodescanner\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.ubercab\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.voghion.app\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.weather.free.forecast.dailyweather\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.westfield.one\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.whatsapp\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.zappntv\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.zhiliaoapp.musically\data_protection.txt
# Output written to eu_top_100/output/Austria/free\com.zzkko\data_protection.txt
# Output written to eu_top_100/output/Austria/free\de.aboutyou.mobile.app\data_protection.txt
# Output written to eu_top_100/output/Austria/free\de.aboutyou.outlet.app\data_protection.txt
# Output written to eu_top_100/output/Austria/free\de.apptiv.business.android.aldi_at\data_protection.txt
# Output written to eu_top_100/output/Austria/free\de.dm.meindm.android\data_protection.txt
# Output written to eu_top_100/output/Austria/free\de.ernstings\data_protection.txt
# Output written to eu_top_100/output/Austria/free\de.hafas.android.oebb\data_protection.txt
# Output written to eu_top_100/output/Austria/free\de.trimexa.urlaubsguru\data_protection.txt
# Output written to eu_top_100/output/Austria/free\de.veedapp.veed\data_protection.txt
# Output written to eu_top_100/output/Austria/free\de.wetteronline.wetterapp\data_protection.txt
# Output written to eu_top_100/output/Austria/free\de.worldiety.photiety.cewe.mc.de\data_protection.txt
# Output written to eu_top_100/output/Austria/free\de.zalando.mobile\data_protection.txt
# Output written to eu_top_100/output/Austria/free\ee.mtakso.client\data_protection.txt
# Output written to eu_top_100/output/Austria/free\org.mozilla.firefox\data_protection.txt
# Output written to eu_top_100/output/Austria/free\org.telegram.messenger\data_protection.txt
# Output written to eu_top_100/output/Austria/free\org.thoughtcrime.securesms\data_protection.txt
# Output written to eu_top_100/output/Austria/free\pdf.pdfreader.viewer.editor.free\data_protection.txt
# Output written to eu_top_100/output/Austria/free\us.zoom.videomeetings\data_protection.txt
# Output written to eu_top_100/output/Austria/paid
data_protection.txt
# Output written to eu_top_100/output/Austria/paid\de.twokit.screen.mirroring.app.chromecast.pro\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\de.twokit.screen.mirroring.app.pro\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\de.twokit.video.tv.cast.browser.firetv.pro\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\de.twokit.video.tv.cast.browser.lg.pro\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\de.twokit.video.tv.cast.browser.samsung.pro\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\it.android.demi.elettronica.pro\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\jp.snowlife01.android.ad_blocker\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\jp.snowlife01.android.rotationcontrolpro\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\mikado.bizcalpro\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\net.dinglisch.android.taskerm\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\net.sarasarasa.lifeup\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\net.techet.netanalyzer.an\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\org.cryptomator\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\org.peakfinder.area.alps\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\org.prowl.torque\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\org.readera.premium\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\org.twisevictory.apps\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\org.withouthat.acalendarplus\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\power.amp.musicplayer.pi.audioplayer\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\pro.gif.videotogif.gifeditor.gifmaker\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\psplay.grill.com\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\ru.iptvremote.android.iptv.pro\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\tech.ula.gimp\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\tech.ula.inkscape\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\tips.routes.peakvisor\data_protection.txt
# Output written to eu_top_100/output/Austria/paid\watch.richface.androidwear.inventor\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\ai.chat.gpt.bot\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\app.nl.socialdeal\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.belfius.directmobile.android\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.belgacom.hello\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.belgacom.mobile.adeleeverywhere\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.bmid.itsme\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.bpost.mybpost\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.burgerprofiel.vlaanderen\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.carrefour.singleapp\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.colruyt.xtra\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.delhaize.my\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.goplay.app\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.goplay.app.tv\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.ixor.doccle.android\data_protection.txt
# Failed to retrieve the page. Unable to find the div with class 'i1GNIe' for be.loterienationaleloterij
# Output written to eu_top_100/output/Belgium/free\be.mobapp.myedenred\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.Nextel.EmergencyApp112\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.nexuzhealth.mobile.mynexuz\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.pizza.android\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.sncbnmbs.b2cmobapp\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.vmma.vtm.zenderapp\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.vrt.dagelijksekost\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\be.vrt.vrtnu\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\bloodpressure.bloodpressureapp.bloodpressuretracker\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\brussels.stib_mivb.floya\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\care.helena.patient\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.action.consumerapp\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.alibaba.aliexpresshd\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.amazon.avod.thirdpartyclient\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.amazon.mShop.android.shopping\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.app.tgtg\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.apple.movetoios\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.appsky.android.bloodpressure\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.appswing.qr.barcodescanner.barcodereader\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.autoscout24\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.azure.authenticator\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.bigwinepot.nwdn.international\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.bloodpressuretracker.bloodbressure.bloodpressurelog\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.bnpp.easybanking\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.bol.shop\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.booking\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.bpfit.bloodpressure.health\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.canda.mobileapp\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.canva.editor\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.casttv.castforchromecast.screencast\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.discord\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.disney.disneyplus\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.documentscan.simplescan.scanpdf\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.duolingo\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.einnovation.temu\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.ezt.pdfreader.pdfviewer\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.facebook.katana\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.facebook.lite\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.facebook.orca\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.ford.fordpass\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.gamma.scan\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.google.android.apps.chromecast.app\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.google.android.apps.translate\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.google.android.apps.walletnfcrel\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.google.android.apps.youtube.kids\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.icemobile.albertheijn\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.ing.banking\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.ingka.ikea.app\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.instagram.android\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.kbc.mobile.android.phone.kbc\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.lemon.lvoverseas\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.lidl.eci.lidlplus\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.lightinthebox.android\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.love.heart.emojigif.sticker.wastickerapp\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.lovebirthday.heartstikers.emojigif.whatsapp\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.lscsmartconnection.smart\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.magic.fluidwallpaper.livefluid\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.maxedadiygroup.brico\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.mcdonalds.mobileapp\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.meetrixonline.drawnames\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com.microsoft.bing\data_protection.txt
# Output written to eu_top_100/output/Belgium/free\com
pro\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.vecturagames.android.app.gpxviewer.pro\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.visiblebody.atlas\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.vitotechnology.StarWalk2\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.volatello.tellofpv\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.wakdev.nfctools.pro\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.watchfacestudio.acro_classic_space1_sirius\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.watchfacestudio.ballozi_vero\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.watchfacestudio.flw098\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.watchfacestudio.flw106\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.watchfacestudio.md307digital\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.watchfacestudio.per023\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.watchfacestudio.s4ufrost\data_protection.txt
# Failed to retrieve the page. Unable to find the div with class 'i1GNIe' for com.watchfacestudio.v15
# Output written to eu_top_100/output/Belgium/paid\com.watchfacestudio.WFP311_Modern_watch_face\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\com.zubersoft.mobilesheetspro\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\cz.acrobits.softphone.alien\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\cz.acrobits.softphone.aliengroundwire\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\de.twokit.screen.mirroring.app.pro\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\de.twokit.video.tv.cast.browser.lg.pro\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\de.twokit.video.tv.cast.browser.samsung.pro\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\de.twokit.video.tv.cast.browser.tivo.pro\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\dev.narikdesign.nothingadaptive\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\gb.xxy.hr\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\it.cpeb.teslaa\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\jp.ne.ibis.ibispaint.app\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\jp.snowlife01.android.rotationcontrolpro\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\net.dinglisch.android.taskerm\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\net.osmand.plus\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\nightradio.relicwaves\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\nl.eerko.boardgamestats\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\nl.jufjannie.letters\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\one.bluelight.dghsop\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\org.prowl.torque\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\org.twisevictory.apps\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\power.amp.musicplayer.pi.audioplayer\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\psplay.grill.com\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\ru.iptvremote.android.iptv.pro\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\se.laxton.ghost\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\smartwatchstudios.app.gears3navigation\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\tech.ula.gimp\data_protection.txt
# Output written to eu_top_100/output/Belgium/paid\tech.ula.inkscape\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\app.vault.android.app\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\bg.abv.andro.emailapp\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\bg.billa.app\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\bg.eko.smile\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\bg.emag.android\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\bg.mobiltel.android.selfcare\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\bg.nepi.spot\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\bg.telenor.mytelenor\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\bg.ubb.mobile\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\bg.vivacom.mobile\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\cn.wps.moffice_eng\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\cn.xiaofengkj.fitpro\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.admiralmarkets.android\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.ai.photoeditor.fx\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.alibaba.aliexpresshd\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.alibaba.intl.android.apps.poseidon\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.apple.movetoios\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.appsky.android.bloodpressure\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.babydola.launcherios\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.begamob.rokuremote\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.bfs.fibank\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.bgmenu.android\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.bloodpressuretracker.bloodbressure.bloodpressurelog\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.booking\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.car.extremesounds.engine\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.christmas.santa.clause.fakecall.prankcall\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.cocacola.app.cee\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.csoft.digitalwallet.android.af.release\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.dais.software.mqes\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.decathlon.app\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.discord\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.diy.boba.drink\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.duolingo\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.econt.prod.pme\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.einnovation.temu\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.evrotrust.app\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.facebook.katana\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.facebook.lite\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.facebook.orca\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.fashiondays.android\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.gamma.scan\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.glovo\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.goeuro.rosie\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.google.android.apps.translate\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.google.android.apps.walletnfcrel\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.google.android.apps.youtube.kids\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.hairclipper.pranksounds.funnyjoke\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.hbo.hbonow\data_protection.txt
# Output written to eu_top_100/output/Bulgaria/free\com.huawei.huaweihealth\data_protection.txt
# ...
# Output written to eu_top_100/output/Malta/free\com.paypal.android.p2pmobile\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.pinterest\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.plexapp.android\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.radio.pocketfm\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.revolut.revolut\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.ryanair.cheapflights\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.sec.android.easyMover\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.snapchat.android\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.spotify.music\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.stremio.one\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.tcl.browser\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.transferwise.android\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.tranzmate\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.ubercab\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.ubercab.driver\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.waze\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.weather.free.forecast.dailyweather\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.westernunion.moneytransferr3app.mt\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.whatsapp\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.whatsapp.w4b\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.wolt.android\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.xiaomi.smarthome\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.xphotokit.chatgptassist\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.zhiliaoapp.musically\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.zpp.music.player\data_protection.txt
# Output written to eu_top_100/output/Malta/free\com.zzkko\data_protection.txt
# Output written to eu_top_100/output/Malta/free\cy.epic.mobilesecurity\data_protection.txt
# Output written to eu_top_100/output/Malta/free\de.flixbus.app\data_protection.txt
# Output written to eu_top_100/output/Malta/free\ee.mtakso.client\data_protection.txt
# Output written to eu_top_100/output/Malta/free\health.sleep.sounds.tracker.alarm.calm\data_protection.txt
# Output written to eu_top_100/output/Malta/free\io.loyale.welbees\data_protection.txt
# Output written to eu_top_100/output/Malta/free\jbl.stc.com\data_protection.txt
# Output written to eu_top_100/output/Malta/free\mt.com.go.iptv.android.devices\data_protection.txt
# Output written to eu_top_100/output/Malta/free\mt.com.go.mygoapp\data_protection.txt
# Output written to eu_top_100/output/Malta/free\mt.think.micheleperesso\data_protection.txt
# Output written to eu_top_100/output/Malta/free\musicplayer.playmusic.audioplayer\data_protection.txt
# Output written to eu_top_100/output/Malta/free\net.diflib.mp3clip\data_protection.txt
# Output written to eu_top_100/output/Malta/free\net.skyscanner.android.main\data_protection.txt
# Output written to eu_top_100/output/Malta/free\org.telegram.messenger\data_protection.txt
# Output written to eu_top_100/output/Malta/free\pdf.pdfreader.viewer.editor.free\data_protection.txt
# Output written to eu_top_100/output/Malta/free\proxy.browser.unblock.sites.proxybrowser.unblocksites\data_protection.txt
# Output written to eu_top_100/output/Malta/free\shareit.lite\data_protection.txt
# Output written to eu_top_100/output/Malta/free\think.hudson\data_protection.txt
# Output written to eu_top_100/output/Malta/free\think.lava\data_protection.txt
# Output written to eu_top_100/output/Malta/free\translate.all.language.translator.cameratranslator\data_protection.txt
# Output written to eu_top_100/output/Malta/free\tv.arte.plus7\data_protection.txt
# Output written to eu_top_100/output/Malta/free\us.zoom.videomeetings\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\app.moertel.retro.iconpack.neon\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\at.bitfire.davdroid\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\ch.threema.app\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.appsgenz.launcherios.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.autolauncher.motorcar\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.birpeso.app\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.birtlapp\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.boost.airplay.receiver\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.booster.gfxpro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.defianttech.diskdiggerpro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.dev47apps.droidcamx\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.digipom.easyvoicerecorder.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.elf.koalasampler\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.ellikurusapp\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.extreamsd.usbaudioplayerpro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.facer.avoStjoiE4\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.finazzi.distquakenoads\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.fluidtouch.noteshelf2\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.g19mobile.gameboosterplus\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.goblintools\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.gsetech.smartiptv2\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.h4xhdv.ffh4xraistarmacrofire\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.imageline.FLM\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.inspirewatchface.gingerbread\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.jrustonapps.myauroraforecastpro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.jrustonapps.myearthquakealertspro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.luma_touch.lumafusion\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.massimobiolcati.irealb\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.maxmpz.audioplayer.unlock\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.medhaapps.wififtpserver.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.monashuniversity.fodmap\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.mxtech.videoplayer.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.myscript.nebo\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.onecode.battle.gfx.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.onetwoapps.mh\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.panda.gamepad\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.panda.mouse\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.pashapuma.pix.material.you.dark\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.pecana.iptvextremepro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.penly.penly\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.peso1peso\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.photopills.android.photopills\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.pnn.obdcardoctor_full\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.prometric.odtt\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.propagator.squeezy\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.recreative.autumnleaves\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.recreative.christmastree\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.recreative.christmasvillage\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.recreative.northpolechristmas\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.riseupgames.proshot2\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.scoregame.gameboosterpro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.shenyaocn.android.usbcamerapro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.simplemobiletools.calendar.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.simplemobiletools.filemanager.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.simplemobiletools.gallery.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.simplemobiletools.thankyou\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.softmedia.receiver\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.sonosaurus.tonalenergytuner\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.SpottedGhosts.SpiritTalker\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.spwatches.bodytemperaturepro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.starwatchfaces.christmascountdown\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.starwatchfaces.scspremium\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.t11.skyview\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.tdr3.hs.android\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.teamspeak.ts3client\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.teslacoilsw.launcher.prime\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.tocaboca.tocacity\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.tocaboca.tocahospital\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.utorrent.client.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.visiblebody.atlas\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.vitotechnology.StarWalk2\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.wakdev.nfctools.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.watchfacestudio.ballozi_vero\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.watchfacestudio.christmaslightswatchface\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.watchfacestudio.flw106\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.watchfacestudio.lrw_christmas\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.watchfacestudio.md307digital\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.watchfacestudio.md324hybrid\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.watchfacestudio.snowflakesrosegold\data_protection.txt
# Failed to retrieve the page. Unable to find the div with class 'i1GNIe' for com.watchfacestudio.v15
# Output written to eu_top_100/output/Malta/paid\com.watchfacestudio.wfp129_digital_watch_face\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.watchfacestudio.WFP311_Modern_watch_face\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.xemsoft.sheetmusicscanner\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\com.zubersoft.mobilesheetspro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\de.adac.camping24\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\de.twokit.screen.mirroring.app.chromecast.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\de.twokit.screen.mirroring.app.firetv.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\de.twokit.screen.mirroring.app.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\de.twokit.screen.mirroring.app.roku.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\de.twokit.video.tv.cast.browser.firetv.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\de.twokit.video.tv.cast.browser.lg.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\de.twokit.video.tv.cast.browser.samsung.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\gb.xxy.hr\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\genz.raistar.macro.fire.gfx.onetap.sensitivity\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\genz.white444.onetap.fire.macro.gfx.sensitivity\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\idm.internet.download.manager.plus\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\inc.trilokia.gfxtool\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\inc.trilokia.pubgfxtool\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\jp.ne.ibis.ibispaint.app\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\jp.snowlife01.android.ad_blocker\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\net.dinglisch.android.taskerm\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\net.esword.esword\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\net.sarasarasa.lifeup\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\org.kustom.widget.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\org.peakfinder.area.alps\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\org.prowl.torque\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\org.readera.premium\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\org.twisevictory.apps\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\power.amp.musicplayer.pi.audioplayer\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\psplay.grill.com\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\psyberia.alpinequest.full\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\ru.iptvremote.android.iptv.pro\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\tech.ula.gimp\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\uk.co.citb.imagitech.gt100.android.vy19.plus\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\uk.co.focusmm.DTSCombo\data_protection.txt
# Output written to eu_top_100/output/Malta/paid\uk.co.tso.ctt\data_protection.txt
# Failed to retrieve the page. Unable to find the div with class 'i1GNIe' for xsoftstudio.musicplayer.pro
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Loop through app directories
#       2 for country in os.listdir('eu_top_100/output'):
# ----> 3     for app in os.listdir(f'eu_top_100/output/{country}/free'):
#       4
#       5         # Define the directory structure
#       6         directory_path = os.path.join(f'eu_top_100/output/{country}/free', app)
#       8         # Process the app page
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'eu_top_100/output/missing_privacy_policy.txt/free'
