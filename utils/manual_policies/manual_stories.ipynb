# %%
import os
import re

def clean_text(text):
    # Remove text between [#ns and ] or [#nsc and ]
    cleaned_text = re.sub(r'\[#ns.*?\]', '', text, flags=re.DOTALL)
    cleaned_text = re.sub(r'\[#nsc.*?\]', '', cleaned_text, flags=re.DOTALL)
    return cleaned_text

def process_privacy_policies(input_directory):
    # Create an output directory if it doesn't exist
    output_directory = 'manual_policies'
    os.makedirs(output_directory, exist_ok=True)

    # Walk through all directories and subdirectories
    for root, dirs, files in os.walk(input_directory):
        for file in files:
            if file == 'privacy_policy.txt':
                input_path = os.path.join(root, file)
                parent_dir = os.path.basename(root)
                output_filename = f'{parent_dir}_privacy_policy'
                output_path = os.path.join(output_directory, output_filename)

                # Read the content of the file
                with open(input_path, 'r', encoding='utf-8') as f:
                    content = f.read()

                # Clean the content
                cleaned_content = clean_text(content)

                # Write the cleaned content to a new file
                with open(output_path, 'w', encoding='utf-8') as f:
                    f.write(cleaned_content)

                print(f'Processed {input_path} -> {output_path}')

# Example usage
input_directory = 'policies_annotated'  # Replace with the path to your directory
process_privacy_policies(input_directory)
# Out:
# Processed policies_annotated\annotated_policies\afmstudio.craigslistclassifiedslocal\privacy_policy.txt -> manual_policies\afmstudio.craigslistclassifiedslocal_privacy_policy
# Processed policies_annotated\annotated_policies\ai.appfront.luckyslice\privacy_policy.txt -> manual_policies\ai.appfront.luckyslice_privacy_policy
# Processed policies_annotated\annotated_policies\ai.blueplate.app\privacy_policy.txt -> manual_policies\ai.blueplate.app_privacy_policy
# Processed policies_annotated\annotated_policies\ai.halloween.aifilter.art\privacy_policy.txt -> manual_policies\ai.halloween.aifilter.art_privacy_policy
# Processed policies_annotated\annotated_policies\aiart.midjourney.dreamnow\privacy_policy.txt -> manual_policies\aiart.midjourney.dreamnow_privacy_policy
# Processed policies_annotated\annotated_policies\at.tomtasche.reader.pro\privacy_policy.txt -> manual_policies\at.tomtasche.reader.pro_privacy_policy
# Processed policies_annotated\annotated_policies\bau.moho.freevpn\privacy_policy.txt -> manual_policies\bau.moho.freevpn_privacy_policy
# Processed policies_annotated\annotated_policies\blizzard.ponderonweather\privacy_policy.txt -> manual_policies\blizzard.ponderonweather_privacy_policy
# Processed policies_annotated\annotated_policies\bloodpressure.bloodpressureapp.bloodpressuretracker\privacy_policy.txt -> manual_policies\bloodpressure.bloodpressureapp.bloodpressuretracker_privacy_policy
# Processed policies_annotated\annotated_policies\com.adv.flixgo.movies\privacy_policy.txt -> manual_policies\com.adv.flixgo.movies_privacy_policy
# Processed policies_annotated\annotated_policies\com.aisecurity\privacy_policy.txt -> manual_policies\com.aisecurity_privacy_policy
# Processed policies_annotated\annotated_policies\Com.app.mmallbooks\privacy_policy.txt -> manual_policies\Com.app.mmallbooks_privacy_policy
# Processed policies_annotated\annotated_policies\Com.app.mypersonalweathermanapp\privacy_policy.txt -> manual_policies\Com.app.mypersonalweathermanapp_privacy_policy
# Processed policies_annotated\annotated_policies\com.appvision.babygenerator.android\privacy_policy.txt -> manual_policies\com.appvision.babygenerator.android_privacy_policy
# Processed policies_annotated\annotated_policies\com.banix.drawsketch.ardraw\privacy_policy.txt -> manual_policies\com.banix.drawsketch.ardraw_privacy_policy
# Processed policies_annotated\annotated_policies\com.brandemaker.dailypost\privacy_policy.txt -> manual_policies\com.brandemaker.dailypost_privacy_policy
# Processed policies_annotated\annotated_policies\com.charstar.andoid\privacy_policy.txt -> manual_policies\com.charstar.andoid_privacy_policy
# Processed policies_annotated\annotated_policies\com.chula.app\privacy_policy.txt -> manual_policies\com.chula.app_privacy_policy
# Processed policies_annotated\annotated_policies\com.cigna.mobile.mycigna\privacy_policy.txt -> manual_policies\com.cigna.mobile.mycigna_privacy_policy
# Processed policies_annotated\annotated_policies\com.company.saturai\privacy_policy.txt -> manual_policies\com.company.saturai_privacy_policy
# Processed policies_annotated\annotated_policies\com.crateandbarrel.ca\privacy_policy.txt -> manual_policies\com.crateandbarrel.ca_privacy_policy
# Processed policies_annotated\annotated_policies\com.directlink.ciqpro\privacy_policy.txt -> manual_policies\com.directlink.ciqpro_privacy_policy
# Processed policies_annotated\annotated_policies\com.discord\privacy_policy.txt -> manual_policies\com.discord_privacy_policy
# Processed policies_annotated\annotated_policies\com.djipilot.gofly\privacy_policy.txt -> manual_policies\com.djipilot.gofly_privacy_policy
# Processed policies_annotated\annotated_policies\com.espn.score_center\privacy_policy.txt -> manual_policies\com.espn.score_center_privacy_policy
# Processed policies_annotated\annotated_policies\com.firstunitedbank.mobile\privacy_policy.txt -> manual_policies\com.firstunitedbank.mobile_privacy_policy
# Processed policies_annotated\annotated_policies\com.green.id\privacy_policy.txt -> manual_policies\com.green.id_privacy_policy
# Processed policies_annotated\annotated_policies\com.homesecurityinnovation.netgearrouter\privacy_policy.txt -> manual_policies\com.homesecurityinnovation.netgearrouter_privacy_policy
# Processed policies_annotated\annotated_policies\com.horoscope.daily.astrology\privacy_policy.txt -> manual_policies\com.horoscope.daily.astrology_privacy_policy
# Processed policies_annotated\annotated_policies\com.imageline.flm\privacy_policy.txt -> manual_policies\com.imageline.flm_privacy_policy
# Processed policies_annotated\annotated_policies\com.inspiredwatchface.gingerbread\privacy_policy.txt -> manual_policies\com.inspiredwatchface.gingerbread_privacy_policy
# Processed policies_annotated\annotated_policies\com.ironlab.whatsweb\privacy_policy.txt -> manual_policies\com.ironlab.whatsweb_privacy_policy
# Processed policies_annotated\annotated_policies\com.jura.coloring.page\privacy_policy.txt -> manual_policies\com.jura.coloring.page_privacy_policy
# Processed policies_annotated\annotated_policies\com.mcdonalds.app\privacy_policy.txt -> manual_policies\com.mcdonalds.app_privacy_policy
# Processed policies_annotated\annotated_policies\com.messages.chat.text.sms.messenger\privacy_policy.txt -> manual_policies\com.messages.chat.text.sms.messenger_privacy_policy
# Processed policies_annotated\annotated_policies\com.mmdarkworld.allkarnote\privacy_policy.txt -> manual_policies\com.mmdarkworld.allkarnote_privacy_policy
# Processed policies_annotated\annotated_policies\Com.money.time\privacy_policy.txt -> manual_policies\Com.money.time_privacy_policy
# Processed policies_annotated\annotated_policies\com.myaichat.com\privacy_policy.txt -> manual_policies\com.myaichat.com_privacy_policy
# Processed policies_annotated\annotated_policies\Com.openai.chatgpt\privacy_policy.txt -> manual_policies\Com.openai.chatgpt_privacy_policy
# Processed policies_annotated\annotated_policies\com.owner.crispyrice\privacy_policy.txt -> manual_policies\com.owner.crispyrice_privacy_policy
# Processed policies_annotated\annotated_policies\Com.owner.revolutionarywings\privacy_policy.txt -> manual_policies\Com.owner.revolutionarywings_privacy_policy
# Processed policies_annotated\annotated_policies\com.penly.penly\privacy_policy.txt -> manual_policies\com.penly.penly_privacy_policy
# Processed policies_annotated\annotated_policies\com.playdigious.deadcells.mobile\privacy_policy.txt -> manual_policies\com.playdigious.deadcells.mobile_privacy_policy
# Processed policies_annotated\annotated_policies\com.simplepilotapps.e6bflightcomputer\privacy_policy.txt -> manual_policies\com.simplepilotapps.e6bflightcomputer_privacy_policy
# Processed policies_annotated\annotated_policies\Com.soccer.score.start\privacy_policy.txt -> manual_policies\Com.soccer.score.start_privacy_policy
# Processed policies_annotated\annotated_policies\com.space.saver.new.photo\privacy_policy.txt -> manual_policies\com.space.saver.new.photo_privacy_policy
# Processed policies_annotated\annotated_policies\com.virus.remover\privacy_policy.txt -> manual_policies\com.virus.remover_privacy_policy
# Processed policies_annotated\annotated_policies\de.twokit.video.tv.cast.browser.lg.pro\privacy_policy.txt -> manual_policies\de.twokit.video.tv.cast.browser.lg.pro_privacy_policy
# Processed policies_annotated\annotated_policies\ee.mtakso.client\privacy_policy.txt -> manual_policies\ee.mtakso.client_privacy_policy
# Processed policies_annotated\annotated_policies\hidden\ai.blueplate.app\privacy_policy.txt -> manual_policies\ai.blueplate.app_privacy_policy
# Processed policies_annotated\annotated_policies\hidden\com.aisecurity\privacy_policy.txt -> manual_policies\com.aisecurity_privacy_policy
# Processed policies_annotated\annotated_policies\hidden\com.discord\privacy_policy.txt -> manual_policies\com.discord_privacy_policy
# Processed policies_annotated\annotated_policies\hidden\com.espn.score_center\privacy_policy.txt -> manual_policies\com.espn.score_center_privacy_policy
# Processed policies_annotated\annotated_policies\hidden\com.firstunitedbank.mobile\privacy_policy.txt -> manual_policies\com.firstunitedbank.mobile_privacy_policy
# Processed policies_annotated\annotated_policies\psplay.grill.com\privacy_policy.txt -> manual_policies\psplay.grill.com_privacy_policy
# Processed policies_annotated\annotated_policies\stepcounter.pedometer.stepstracker\privacy_policy.txt -> manual_policies\stepcounter.pedometer.stepstracker_privacy_policy

# %%
import os

def count_words(text):
    words = text.split()
    return len(words)

def generate_report(directory):
    report_lines = []
    total_words = 0
    file_count = 0

    for root, dirs, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)

            with open(file_path, 'r', encoding='utf-8') as f:
                content = f.read()

            word_count = count_words(content)
            total_words += word_count
            file_count += 1
            report_lines.append(f'{file}: {word_count} words')

    average_word_count = total_words / file_count if file_count > 0 else 0
    report_lines.append(f'\nAverage word count: {average_word_count:.2f}')

    report_path = os.path.join(directory, 'report.txt')

    with open(report_path, 'w', encoding='utf-8') as report_file:
        report_file.write('\n'.join(report_lines))

    print(f'Report generated at {report_path}')

# Example usage
manual_policies_directory = 'manual_policies'  # Replace with the path to your manual_policies directory if different
generate_report(manual_policies_directory)
# Out:
# Report generated at manual_policies\report.txt
